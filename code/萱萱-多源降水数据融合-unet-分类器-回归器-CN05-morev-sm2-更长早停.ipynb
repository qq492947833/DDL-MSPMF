# %%
import Auto_paint_self

# %%
CN05_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\CN05.1_Pre_1961_2021_daily_025x025.nc','pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
CMO_RPH,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\CMORPH_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
ERA5_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\ERA5_China_2001_2022_2.nc','tp','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
td2m,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\2m-dewpoint-temperature-day.nc','d2m','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
t2m,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\2m-temperature-day.nc','t2m','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
sp,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\Surface-pressure-day.nc','sp','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
sm,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\Volumetric-soil-water-layer-1-day.nc','swvl1','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
GPM_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\GPM_China_2001_2022_time.nc','precipitation','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
GSMAP_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\GSMAP_China_2001_2022_time.nc','Pre_daily','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
MSWEP_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\MSWEP_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
PERSIANN_CDR_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\PERSIANN_CDR_PRE_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\xarray\coding\times.py:170: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
import numpy as np
vx=np.zeros((CMO_RPH.shape[0],CMO_RPH.shape[1],CMO_RPH.shape[2],10))
vy=np.zeros((CN05_PRE.shape[0],CN05_PRE.shape[1],CN05_PRE.shape[2]),dtype='int32')
CN05_PRE=CN05_PRE[:,::-1,:]
CN05_PRE=np.nan_to_num(CN05_PRE,nan=0)
vx[:,:,:,0]=CMO_RPH
vx[:,:,:,1]=ERA5_PRE
vx[:,:,:,2]=GPM_PRE
vx[:,:,:,3]=GSMAP_PRE
vx[:,:,:,4]=MSWEP_PRE
vx[:,:,:,5]=PERSIANN_CDR_PRE
vx[:,:,:,6]=td2m
vx[:,:,:,7]=t2m
vx[:,:,:,8]=sp
vx[:,:,:,9]=sm
vx=np.nan_to_num(vx,nan=0)
for i in range(CN05_PRE.shape[1]):
    for j in range(CN05_PRE.shape[2]):
        vy[np.array(CN05_PRE[:,i,j])<0.1,i,j]=0
        vy[np.array(CN05_PRE[:,i,j])>=0.1,i,j]=1

vx=(vx-np.nanmean(vx,axis=0))/np.nanstd(vx,axis=0)
vx=np.nan_to_num(vx,nan=0)
CN05_PRE=(CN05_PRE-np.nanmean(CN05_PRE,axis=0))/np.nanstd(CN05_PRE,axis=0)
CN05_PRE=np.nan_to_num(CN05_PRE,nan=0)
# Out:
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1532796\1891578375.py:22: RuntimeWarning: invalid value encountered in divide
#   vx=(vx-np.nanmean(vx,axis=0))/np.nanstd(vx,axis=0)
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1532796\1891578375.py:24: RuntimeWarning: invalid value encountered in divide
#   CN05_PRE=(CN05_PRE-np.nanmean(CN05_PRE,axis=0))/np.nanstd(CN05_PRE,axis=0)

# %%
print(np.isnan(vx).any(),np.isnan(CN05_PRE).any(),np.isnan(vy).any())
# Out:
# False False False

# %%
from keras.models import load_model
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # 设置只使用 GPU 0
        tf.config.set_visible_devices(gpus[1], 'GPU')
        # 设置 GPU 0 的内存动态增长
        tf.config.experimental.set_memory_growth(gpus[1], True)
    except RuntimeError as e:
        print(e)
model=load_model(r'E:/xuanxuan/xuanxuan_unet_classify_CN05_morev_sm2')
vx_last=model.predict(vx,batch_size=40)
# Out:
# 192/192 [==============================] - 57s 74ms/step

# %%
vx_last[vx_last<=0.5]=0
vx_last[vx_last>0.5]=1

# %%
vx_new=np.zeros((CMO_RPH.shape[0],CMO_RPH.shape[1],CMO_RPH.shape[2],11))
vx_new[:,:,:,:10]=vx
vx_new[:,:,:,10]=vx_last.reshape(vx_last.shape[0],vx_last.shape[1],vx_last.shape[2])

# %%
print(np.isnan(vx_new).any())
# Out:
# False

# %%
from keras.models import load_model
index=int((1-0.2)*CN05_PRE.shape[0])
trainy=CN05_PRE[:index,:,:]
testy=CN05_PRE[index:,:,:]
trainx=vx_new[:index,:,:,:]
testx=vx_new[index:,:,:,:]
model=load_model(r'E:/xuanxuan/xuanxuan_unet_classify_regress_CN05_morev_sm2')
predicty = model.predict(testx,batch_size=40)
# Out:
# 39/39 [==============================] - 4s 85ms/step

# %%
time=times[index:]

# %%
CN05_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\CN05.1_Pre_1961_2021_daily_025x025.nc','pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
CN05_PRE=CN05_PRE[:,::-1,:]
lat=lat[::-1]
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\xarray\coding\times.py:170: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
predicty=predicty.reshape(predicty.shape[0],predicty.shape[1],predicty.shape[2])*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)
testy=testy*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1718308\352614743.py:1: RuntimeWarning: Mean of empty slice
#   predicty=predicty.reshape(predicty.shape[0],predicty.shape[1],predicty.shape[2])*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1718308\352614743.py:2: RuntimeWarning: Mean of empty slice
#   testy=testy*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)

# %%
Auto_paint_self.create_nc(time,lat,lon,None,predicty,'time','lat','lon','predicty','no',None,'yes','yes','yes','E:/xuanxuan/unet_pre_predicty_CN05_morev_sm2.nc')
Auto_paint_self.create_nc(time,lat,lon,None,testy,'time','lat','lon','testy','no',None,'yes','yes','yes','E:/xuanxuan/unet_pre_testy_CN05_morev_sm2.nc')

# %%
r=np.zeros((testx.shape[1],testx.shape[2]))
p=np.zeros((testx.shape[1],testx.shape[2]))
from scipy.stats import pearsonr
for i in range(testx.shape[1]):
    for j in range(testx.shape[2]):
        if np.isnan(CN05_PRE[:,i,j]).any():
            r[i,j],p[i,j]=np.nan,np.nan
        else:
            r[i,j],p[i,j] = pearsonr(predicty[:,i,j],testy[:,i,j])
print(np.nanmean(r))
# Out:
# 0.7325800370716685

# %%
#用于生成unet网络
def Auto_Unet(vy,vx,downnum,covnum,test_size=0.2,valid_size=0.1,k_fold=None,task_mode='regression',if_best_mode='no',modelpath=None,ifrandom_split='yes',baselayer=64,cov_method='cov',cov_kernelsize=3,cov_strides=1,pool_method='maxpooling',pool_kernel_size=2,pool_strides=2,ifnormalization='no',normalization_method=None,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,activate='tanh',if_last_act='no',if_print_model='yes',loss_function='default',optimizer='SGD',metrics='default',if_early_stopping=None,learning_rate=0.01,epochs=2000,batch_size=20,ifweight='yes',ifmute='no',ifsave='no',savepath=None,device='cpu'):
    import tensorflow as tf
    if device=='gpu':
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            try:
                # 设置只使用 GPU 0
                tf.config.set_visible_devices(gpus[1], 'GPU')
                # 设置 GPU 0 的内存动态增长
                tf.config.experimental.set_memory_growth(gpus[1], True)
            except RuntimeError as e:
                print(e)
    else:
        import os
        os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
    from tensorflow.keras.models import Sequential,Model
    import math
    from tensorflow.python.keras.layers.core import Activation,Dropout,Dense,Flatten
    from tensorflow.keras.layers import BatchNormalization,LayerNormalization,LocallyConnected2D,Conv2D,MaxPooling2D,AveragePooling2D,Input,UpSampling2D,ZeroPadding2D
    from sklearn.model_selection import train_test_split
    from sklearn.model_selection import KFold
    import numpy as np
    import tensorflow.keras
    from tensorflow.keras.optimizers import SGD,Adam
    from scipy.stats import pearsonr
    from tensorflow.python.keras.layers.merge import concatenate
    import os
    from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
    from keras.models import load_model
    import sklearn
    import copy
    from sklearn.utils.class_weight import compute_class_weight
    from tensorflow.keras import backend as K
    import warnings
    warnings.filterwarnings("ignore")
    
    if task_mode=='regression':
        if loss_function=='default' or loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanAbsoluteError':
            loss=tf.keras.losses.MeanAbsoluteError()
        elif loss_function=='MeanAbsolutePercentageError':
            loss=tf.keras.losses.MeanAbsolutePercentageError()
        elif loss_function=='MeanSquaredLogarithmicError':
            loss=tf.keras.losses.MeanSquaredLogarithmicError()
        elif loss_function=='CosineSimilarity':
            loss=tf.keras.losses.CosineSimilarity()
        elif loss_function=='Huber':
            loss=tf.keras.losses.Huber()
        elif loss_function=='LogCosh':
            loss=tf.keras.losses.LogCosh()
        elif loss_function=='Pearsonr':
            def loss_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            loss=loss_pearsonr
        if metrics=='default' or metrics=='MeanSquaredError':
            metric=tf.keras.metrics.MeanSquaredError()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='MeanAbsolutePercentageError':
            metric=tf.keras.metrics.MeanAbsolutePercentageError()
        elif metrics=='MeanSquaredLogarithmicError':
            metric=tf.keras.metrics.MeanSquaredLogarithmicError()
        elif metrics=='CosineSimilarity':
            metric=tf.keras.metrics.CosineSimilarity()
        elif metrics=='LogCoshError':
            metric=tf.keras.metrics.LogCoshError()
        elif metrics=='Pearsonr':
            def metrics_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            metric=metrics_pearsonr
    elif task_mode=='binary_classify':
        if loss_function=='default' or loss_function=='BinaryCrossentropy':
            loss=tf.keras.losses.BinaryCrossentropy()
        elif loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        elif loss_function=='f1':
            def loss_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return 1 - f1
            loss=loss_f1
        if metrics=='default' or metrics=='BinaryAccuracy':
            metric=tf.keras.metrics.BinaryAccuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='BinaryCrossentropy':
            metric=tf.keras.metrics.BinaryCrossentropy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
        elif metrics=='AUC':
            metric=tf.keras.metrics.AUC()
        elif metrics=='Precision':
            metric=tf.keras.metrics.Precision()
        elif metrics=='Recall':
            metric=tf.keras.metrics.Recall()
        elif metrics=='TruePositives':
            metric=tf.keras.metrics.TruePositives()
        elif metrics=='TrueNegatives':
            metric=tf.keras.metrics.TrueNegatives()
        elif metrics=='FalsePositives':
            metric=tf.keras.metrics.FalsePositives()
        elif metrics=='FalseNegatives':
            metric=tf.keras.metrics.FalseNegatives()
        elif metrics=='PrecisionAtRecall':
            metric=tf.keras.metrics.PrecisionAtRecall()
        elif metrics=='SensitivityAtSpecificity':
            metric=tf.keras.metrics.SensitivityAtSpecificity()
        elif metrics=='SpecificityAtSensitivity':
            metric=tf.keras.metrics.SpecificityAtSensitivity()
        elif metrics=='f1':
            def metric_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return f1
            metric=metric_f1
    elif task_mode=='multi_classify':
        if loss_function=='default' or loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        if metrics=='default' or metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
    weights=0
    model=0
    if vy.ndim==3:
        vy=vy.reshape(vy.shape[0],vy.shape[1],vy.shape[2],1)
    model=None
    predicty=None
    testy=None
    r=None
    p=None
    k=0
    total_covnum=0
    if ifrandom_split=='yes':
        trainy,testy,trainx,testx = train_test_split(vy,vx,test_size=test_size,random_state=25)
    else:
        index=int((1-test_size)*vy.shape[0])
        trainy=vy[:index,:,:,:]
        testy=vy[index:,:,:,:]
        trainx=vx[:index,:,:,:]
        testx=vx[index:,:,:,:]
    if task_mode!='regression':
        def create_sample_weights_for_batch_multitask(y_batch_multitask, list_of_task_weights_dicts):
            batch_size, height, width, num_tasks = y_batch_multitask.shape
            
            if len(list_of_task_weights_dicts) != num_tasks:
                raise ValueError(f"Number of tasks in y_batch_multitask ({num_tasks}) "
                                 f"must match length of list_of_task_weights_dicts ({len(list_of_task_weights_dicts)}).")
        
            sample_weight_batch = np.ones_like(y_batch_multitask, dtype=np.float32)
        
            for i in range(num_tasks):
                task_labels_current_channel = y_batch_multitask[..., i]
                weights_dict_for_task_i = list_of_task_weights_dicts[i]
                
                weight_for_0 = weights_dict_for_task_i.get(0, 1.0)
                weight_for_1 = weights_dict_for_task_i.get(1, 1.0)
                
                sample_weight_batch[..., i][task_labels_current_channel == 0] = weight_for_0
                sample_weight_batch[..., i][task_labels_current_channel == 1] = weight_for_1
                
            return sample_weight_batch
        def compute_unified_class_weights(y, task_mode=task_mode):
            if task_mode == 'binary_classify':
                if y.ndim == 4 and y.shape[-1] > 1:
                    num_tasks = y.shape[-1]
                    list_of_task_weights_dicts = []
                    possible_binary_classes = np.array([0, 1])
                    for i in range(num_tasks):
                        y_task_i_flat = y[..., i].ravel()
                        if len(y_task_i_flat) == 0:
                            weights_dict_task_i = {0: 1.0, 1: 1.0} 
                        else:
                            valid_labels_mask = np.isin(y_task_i_flat, possible_binary_classes)
                            if not np.all(valid_labels_mask) and np.any(valid_labels_mask): 
                                y_task_i_flat_filtered = y_task_i_flat[valid_labels_mask]
                                if len(y_task_i_flat_filtered) == 0 : y_task_i_flat_filtered = np.array([0]) 
                            elif not np.any(valid_labels_mask): 
                                 y_task_i_flat_filtered = np.array([0]) 
                            else:
                                y_task_i_flat_filtered = y_task_i_flat
                            class_weights_arr = compute_class_weight(
                                class_weight='balanced',
                                classes=possible_binary_classes, 
                                y=y_task_i_flat_filtered
                            )
                            weights_dict_task_i = dict(zip(possible_binary_classes, class_weights_arr))
                        list_of_task_weights_dicts.append(weights_dict_task_i)
                    return list_of_task_weights_dicts 
        
                else: 
                    y_flat = y.ravel()
                    possible_binary_classes = np.array([0, 1])
                    valid_labels_mask = np.isin(y_flat, possible_binary_classes)
                    if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                        y_flat_filtered = y_flat[valid_labels_mask]
                        if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0])
                    elif not np.any(valid_labels_mask):
                         y_flat_filtered = np.array([0])
                    else:
                        y_flat_filtered = y_flat
        
                    class_weights_arr = compute_class_weight(
                        class_weight='balanced',
                        classes=possible_binary_classes,
                        y=y_flat_filtered
                    )
                    return dict(zip(possible_binary_classes, class_weights_arr)) 
        
            elif task_mode == 'multi_classify':
                y_flat = y.ravel()
                possible_multiclass_classes = np.arange(int(np.max(y)+1))
                valid_labels_mask = np.isin(y_flat, possible_multiclass_classes)
                if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                    y_flat_filtered = y_flat[valid_labels_mask]
                    if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0]) 
                elif not np.any(valid_labels_mask):
                    y_flat_filtered = np.array([0]) 
                else:
                    y_flat_filtered = y_flat
                    
                class_weights_arr = compute_class_weight(
                    class_weight='balanced',
                    classes=possible_multiclass_classes,
                    y=y_flat_filtered
                )
                return dict(zip(possible_multiclass_classes, class_weights_arr)) 
            else:
                raise ValueError(f"Unsupported task_mode: {task_mode}")
        def create_unified_sample_weights_for_batch(y_batch, unified_class_weights):
            if isinstance(unified_class_weights, list):
                if not (y_batch.ndim == 4 and y_batch.shape[-1] == len(unified_class_weights)):
                     raise ValueError(f"Shape mismatch for multi-task binary weights. "
                                      f"y_batch shape: {y_batch.shape}, num_weight_dicts: {len(unified_class_weights)}")
                return create_sample_weights_for_batch_multitask(y_batch, unified_class_weights)
            elif isinstance(unified_class_weights, dict):
                y_int_labels_for_weights = y_batch
                if y_batch.ndim > 0 and y_batch.shape[-1] == 1 and y_batch.ndim >=2 : 
                    y_int_labels_for_weights = np.squeeze(y_batch, axis=-1)
                sample_weight_for_batch = np.ones_like(y_int_labels_for_weights, dtype=np.float32)
                for class_label, weight in unified_class_weights.items():
                    sample_weight_for_batch[y_int_labels_for_weights == class_label] = weight
                
                return sample_weight_for_batch
            else:
                raise TypeError(f"unified_class_weights has unexpected type: {type(unified_class_weights)}. Expected dict or list.")
        def train_data_generator(x, y, batch_size, task_mode=task_mode):
            num_samples = x.shape[0]
            global_unified_weights = compute_unified_class_weights(y, task_mode)
            while True:
                indices = np.arange(num_samples)
                
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    if len(batch_indices) == 0:
                        continue
        
                    x_batch = x[batch_indices]
                    y_batch = y[batch_indices] 
                    sample_weight_batch = create_unified_sample_weights_for_batch(
                        y_batch, 
                        global_unified_weights
                    )
                    yield x_batch, y_batch, sample_weight_batch
    else:
        def train_data_generator(x, y, batch_size):
            num_samples = x.shape[0]
            while True:
                indices = np.arange(num_samples)
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    x_batch = x[batch_indices]  
                    y_batch = y[batch_indices]      
                    
                    yield x_batch, y_batch
    def test_data_generator(x, batch_size):
        num_samples = x.shape[0]
        while True:
            indices = np.arange(num_samples)
            
            for start in range(0, num_samples, batch_size):
                end = min(start + batch_size, num_samples)
                batch_indices = indices[start:end]
                
                x_batch = x[batch_indices]  # 第一个输入特征
                
                yield x_batch
    if if_best_mode=='no':
        W=trainx.shape[1]
        H=trainx.shape[2]
        for i in range(int(downnum-1)):
            W=math.floor(((W-pool_kernel_size)/pool_strides)+1)
            H=math.floor(((H-pool_kernel_size)/pool_strides)+1)
        if W<1 or H<1:
            print('下采样次数过多,导致最下层图形长度/宽度小于1!')
            return model,predicty,testy,r,p
        if pool_strides!=pool_kernel_size:
            print('池化步长和池化核不等,将导致下采样前后通道数相除不为整数！')
            return model,predicty,testy,r,p
        upsize=pool_strides
        inputs=Input((trainx.shape[1],trainx.shape[2],trainx.shape[3],))
        for i in range(int(downnum)):
            for j in range(int(covnum)):
                if cov_method=='cov':
                    if if_weight_initialize=='no':
                        if total_covnum ==0:
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(inputs))')
                        else:
                            if j==0:
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(pool'+str(i)+'))')
                            else:
                                if ifnormalization=='yes':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(norm'+str(i+1)+'))')
                                else:
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(cov'+str(i+1)+'))')
                    elif if_weight_initialize=='yes':
                        if total_covnum==0:
                            if weight_initialize_method=='RandomNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(inputs))')
                            elif weight_initialize_method=='RandomUniform':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(inputs))')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-(trainx.shape[1]/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-(trainx.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same", kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(inputs))')
                        else:
                            if j==0:
                                if weight_initialize_method=='RandomNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(pool'+str(i)+'))')
                                elif weight_initialize_method=='RandomUniform':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(pool'+str(i)+'))')
                                elif weight_initialize_method=='TruncatedNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-(pool'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-(pool'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(pool'+str(i)+'))')
                            else:
                                if ifnormalization=='yes':
                                    if weight_initialize_method=='RandomNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                    elif weight_initialize_method=='RandomUniform':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                    elif weight_initialize_method=='TruncatedNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(norm'+str(i+1)+'))')
                                else:
                                    if weight_initialize_method=='RandomNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                    elif weight_initialize_method=='RandomUniform':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                    elif weight_initialize_method=='TruncatedNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(cov'+str(i+1)+'))')
                elif cov_method=='localcov':
                    if if_weight_initialize=='no':
                        if total_covnum==0:
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(inputs))')
                        else:
                            if j==0:
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(pool'+str(i)+'))')
                            else:
                                if ifnormalization=='yes':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(norm'+str(i+1)+'))')
                                else:
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(cov'+str(i+1)+'))')
                    elif if_weight_initialize=='yes':
                        if total_covnum==0:
                            if weight_initialize_method=='RandomNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate, kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(inputs))')
                            elif weight_initialize_method=='RandomUniform':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate, kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(inputs))')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[1]-((trainx.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((trainx.shape[2]-((trainx.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate, kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(inputs))')
                        else:
                            if j==0:
                                if weight_initialize_method=='RandomNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(pool'+str(i)+'))')
                                elif weight_initialize_method=='RandomUniform':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(pool'+str(i)+'))')
                                elif weight_initialize_method=='TruncatedNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[1]-((pool'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((pool'+str(i)+'.shape[2]-((pool'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(pool'+str(i)+'))')
                            else:
                                if ifnormalization=='yes':
                                    if weight_initialize_method=='RandomNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                    elif weight_initialize_method=='RandomUniform':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                    elif weight_initialize_method=='TruncatedNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(norm'+str(i+1)+'))')
                                else:
                                    if weight_initialize_method=='RandomNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                    elif weight_initialize_method=='RandomUniform':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                    elif weight_initialize_method=='TruncatedNormal':
                                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(cov'+str(i+1)+'))')
                total_covnum=total_covnum+1
                if ifnormalization=='yes':
                    if normalization_method=='batchnormalization':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(cov'+str(i+1)+')')
                    elif normalization_method=='layernormalization':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(cov'+str(i+1)+')')
            k=k+1
            if i!=(downnum-1):
                baselayer=baselayer*2
            if pool_method=='maxpooling' and i!=(downnum-1):
                if ifnormalization=='yes':
                    exec('pool'+str(i+1)+'=MaxPooling2D(pool_size=(pool_kernel_size,pool_kernel_size),strides=pool_strides)(norm'+str(i+1)+')')
                else:
                    exec('pool'+str(i+1)+'=MaxPooling2D(pool_size=(pool_kernel_size,pool_kernel_size),strides=pool_strides)(cov'+str(i+1)+')')
            elif pool_method=='avepooling' and i!=(downnum-1):
                if ifnormalization=='yes':
                    exec('pool'+str(i+1)+'=AveragePooling2D(pool_size=(pool_kernel_size,pool_kernel_size),strides=pool_strides)(norm'+str(i+1)+')')
                else:
                    exec('pool'+str(i+1)+'=AveragePooling2D(pool_size=(pool_kernel_size,pool_kernel_size),strides=pool_strides)(cov'+str(i+1)+')')
        l=k-1
        k=k+1
        for i in range(downnum,2*downnum-1):
            baselayer=int(baselayer/2)
            if cov_method=='cov':
                if if_weight_initialize=='no':
                    if ifnormalization=='yes':
                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(norm'+str(i)+'))')
                    else:
                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(cov'+str(i)+'))')
                elif if_weight_initialize=='yes':
                    if ifnormalization=='yes':
                        if weight_initialize_method=='RandomNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+'))')
                        elif weight_initialize_method=='RandomUniform':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+'))')
                        elif weight_initialize_method=='TruncatedNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-(norm'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-(norm'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(norm'+str(i)+'))')
                    else:
                        if weight_initialize_method=='RandomNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(cov'+str(i)+'))')
                        elif weight_initialize_method=='RandomUniform':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(cov'+str(i)+'))')
                        elif weight_initialize_method=='TruncatedNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-(cov'+str(i)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-(cov'+str(i)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(cov'+str(i)+'))')
            elif cov_method=='localcov':
                if if_weight_initialize=='no':
                    if ifnormalization=='yes':
                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(norm'+str(i)+'))')
                    else:
                        exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(cov'+str(i)+'))')
                elif if_weight_initialize=='yes':
                    if ifnormalization=='yes':
                        if weight_initialize_method=='RandomNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+'))')
                        elif weight_initialize_method=='RandomUniform':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+'))')
                        elif weight_initialize_method=='TruncatedNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[1]-((norm'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i)+'.shape[2]-((norm'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(norm'+str(i)+'))')
                    else:
                        if weight_initialize_method=='RandomNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(cov'+str(i)+'))')
                        elif weight_initialize_method=='RandomUniform':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(cov'+str(i)+'))')
                        elif weight_initialize_method=='TruncatedNormal':
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[1]-((cov'+str(i)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i)+'.shape[2]-((cov'+str(i)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(cov'+str(i)+'))')
            if ifnormalization=='yes':
                if normalization_method=='batchnormalization':
                    exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(cov'+str(i+1)+')')
                elif normalization_method=='layernormalization':
                    exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(cov'+str(i+1)+')')
            if ifnormalization=='yes':
                covup=eval('norm'+str(k))
                covdown=eval('norm'+str(l))
            else:
                covup=eval('cov'+str(k))
                covdown=eval('cov'+str(l))
            exec('up'+str(i+1)+'=concatenate([ZeroPadding2D(padding=((math.floor((covdown.shape[1]-covup.shape[1]*upsize)/2),math.ceil((covdown.shape[1]-covup.shape[1]*upsize)/2)),(math.floor((covdown.shape[2]-covup.shape[2]*upsize)/2),math.ceil((covdown.shape[2]-covup.shape[2]*upsize)/2))))(UpSampling2D(size=(upsize, upsize))(covup)), covdown], axis=3)')
            for j in range(int(covnum)):
                if cov_method=='cov':
                    if if_weight_initialize=='no':
                        if j==0:
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(up'+str(i+1)+'))')
                        else:
                            if ifnormalization=='yes':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(norm'+str(i+1)+'))')
                            else:
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same")(cov'+str(i+1)+'))')
                    elif if_weight_initialize=='yes':
                        if j==0:
                            if weight_initialize_method=='RandomNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(up'+str(i+1)+'))')
                            elif weight_initialize_method=='RandomUniform':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(up'+str(i+1)+'))')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-(up'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-(up'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(up'+str(i+1)+'))')
                        else:
                            if ifnormalization=='yes':
                                if weight_initialize_method=='RandomNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                elif weight_initialize_method=='RandomUniform':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                elif weight_initialize_method=='TruncatedNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-(norm'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-(norm'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(norm'+str(i+1)+'))')
                            else:
                                if weight_initialize_method=='RandomNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                elif weight_initialize_method=='RandomUniform':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                elif weight_initialize_method=='TruncatedNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-(cov'+str(i+1)+'.shape[1]/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-(cov'+str(i+1)+'.shape[2]/cov_strides)))/2))))(Conv2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,padding="same",kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(cov'+str(i+1)+'))')
                elif cov_method=='localcov':
                    if if_weight_initialize=='no':
                        if j==0:
                            exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(up'+str(i+1)+'))')
                        else:
                            if ifnormalization=='yes':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(norm'+str(i+1)+'))')
                            else:
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate)(cov'+str(i+1)+'))')
                    elif if_weight_initialize=='yes':
                        if j==0:
                            if weight_initialize_method=='RandomNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(up'+str(i+1)+'))')
                            elif weight_initialize_method=='RandomUniform':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(up'+str(i+1)+'))')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[1]-((up'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((up'+str(i+1)+'.shape[2]-((up'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(up'+str(i+1)+'))')
                        else:
                            if ifnormalization=='yes':
                                if weight_initialize_method=='RandomNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                elif weight_initialize_method=='RandomUniform':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i+1)+'))')
                                elif weight_initialize_method=='TruncatedNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[1]-((norm'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((norm'+str(i+1)+'.shape[2]-((norm'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(norm'+str(i+1)+'))')
                            else:
                                if weight_initialize_method=='RandomNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                elif weight_initialize_method=='RandomUniform':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(cov'+str(i+1)+'))')
                                elif weight_initialize_method=='TruncatedNormal':
                                    exec('cov'+str(i+1)+'=ZeroPadding2D(padding=((math.floor(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[1]-((cov'+str(i+1)+'.shape[1]-cov_kernelsize+1)/cov_strides)))/2)),(math.floor(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2),math.ceil(math.floor((cov'+str(i+1)+'.shape[2]-((cov'+str(i+1)+'.shape[2]-cov_kernelsize+1)/cov_strides)))/2))))(LocallyConnected2D(baselayer,(cov_kernelsize,cov_kernelsize),strides=cov_strides,activation=activate,kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2,metrics="MeanSquaredError"))(cov'+str(i+1)+'))')
                if ifnormalization=='yes':
                    if normalization_method=='batchnormalization':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(cov'+str(i+1)+')')
                    elif normalization_method=='layernormalization':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(cov'+str(i+1)+')')
            k=k+1
            l=l-1
        if if_last_act!='no':
            if task_mode=='multi_classify':
                if ifnormalization=='yes':
                    outputs=eval('Conv2D(int(np.max(vy))+1, (1, 1),strides=(1,1),padding="same",activation=if_last_act)(norm'+str(2*downnum-1)+')')
                else:
                    outputs=eval('Conv2D(int(np.max(vy))+1, (1, 1),strides=(1,1),padding="same",activation=if_last_act)(cov'+str(2*downnum-1)+')')
            else:
                if ifnormalization=='yes':
                    outputs=eval('Conv2D(vy.shape[3], (1, 1),strides=(1,1),padding="same",activation=if_last_act)(norm'+str(2*downnum-1)+')')
                else:
                    outputs=eval('Conv2D(vy.shape[3], (1, 1),strides=(1,1),padding="same",activation=if_last_act)(cov'+str(2*downnum-1)+')')
        else:
            if task_mode=='multi_classify':
                if ifnormalization=='yes':
                    outputs=eval('Conv2D(int(np.max(vy))+1, (1, 1),strides=(1,1),padding="same")(norm'+str(2*downnum-1)+')')
                else:
                    outputs=eval('Conv2D(int(np.max(vy))+1, (1, 1),strides=(1,1),padding="same")(cov'+str(2*downnum-1)+')')
            else:
                if ifnormalization=='yes':
                    outputs=eval('Conv2D(vy.shape[3], (1, 1),strides=(1,1),padding="same")(norm'+str(2*downnum-1)+')')
                else:
                    outputs=eval('Conv2D(vy.shape[3], (1, 1),strides=(1,1),padding="same")(cov'+str(2*downnum-1)+')')
        model=eval('Model(inputs=inputs, outputs=outputs)')
        if optimizer == 'SGD':
            opt = SGD(lr = learning_rate)
        elif optimizer == 'Adam':
            opt = Adam(lr = learning_rate)
        model.compile(loss=loss,optimizer=opt,metrics=[metric])
    elif if_best_mode=='yes' or if_best_mode=='load':
        if k_fold!=None:
            models=[]
            for i in range(k_fold):
                models.append(load_model(modelpath+'_'+str(i+1)))
        else:
            model=load_model(modelpath)
    if if_print_model=='yes':
        if k_fold!=None:
            if if_best_mode=='yes' or if_best_mode=='load':
                print(models[0].summary())
            else:
                print(model.summary())
        else:
            print(model.summary())
    if epochs!=0:
        if valid_size!=None or k_fold !=None:
            if k_fold!=None:
                if if_best_mode=='no' :
                    models = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold = trainx[train_idx], trainy[train_idx]
                        X_val_fold, y_val_fold = trainx[val_idx], trainy[val_idx]
                        model=eval('Model(inputs=inputs, outputs=outputs)')
                        model.compile(loss=loss,optimizer=opt,metrics=[metric])
                        if if_early_stopping!=None:
                            H = model.fit(train_data_generator(X_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = model.fit(train_data_generator(X_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models.append(model)
                else:
                    models_new = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold = trainx[train_idx], trainy[train_idx]
                        X_val_fold, y_val_fold = trainx[val_idx], trainy[val_idx]
                        if if_early_stopping!=None:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models_new.append(models[fold_no])
                    models=models_new
            else:
                if ifrandom_split=='yes':
                    trainy,validy,trainx,validx = train_test_split(trainy,trainx,test_size=valid_size/(1-test_size),random_state=25)
                else:
                    index=int((1-valid_size/(1-test_size))*trainy.shape[0])
                    validy=trainy[index:]
                    trainy=trainy[:index]
                    validx=trainx[index:]
                    trainx=trainx[:index]
                if if_early_stopping!=None:
                    H = model.fit(train_data_generator(trainx,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                else:
                    H = model.fit(train_data_generator(trainx,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs)
        else:
            if if_early_stopping!=None:
                H = model.fit(train_data_generator(trainx,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
            else:
                H = model.fit(train_data_generator(trainx,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs)
    if k_fold!=None:
        predicty = [model.predict(test_data_generator(testx,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0))) for model in models]
        predicty=np.nanmean(predicty,axis=0)
    else:
        predicty = model.predict(test_data_generator(testx,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)))
    predicty = np.nan_to_num(predicty,nan=0)
    r=np.zeros((testx.shape[1],testx.shape[2],testy.shape[3]))
    p=np.zeros((testx.shape[1],testx.shape[2],testy.shape[3]))
    f1score=np.zeros((testx.shape[1],testx.shape[2],testy.shape[3]))
    accuracyscore=np.zeros((testx.shape[1],testx.shape[2],testy.shape[3]))
    recallscore=np.zeros((testx.shape[1],testx.shape[2],testy.shape[3]))
    precisionscore=np.zeros((testx.shape[1],testx.shape[2],testy.shape[3]))
    predicty=predicty.reshape(predicty.shape[0],predicty.shape[1],predicty.shape[2],predicty.shape[3])
    for i in range(testx.shape[1]):
        for j in range(testx.shape[2]):
            for k in range(testy.shape[3]):
                if task_mode=='regression':
                    r[i,j,k],p[i,j,k] = pearsonr(predicty[:,i,j,k],testy[:,i,j,k])
                    r[i,j,k]=np.nan_to_num(r[i,j,k],nan=0)
                elif task_mode=='binary_classify':
                    predicty[:,i,j,k]=[int(round(predicty[l,i,j,k],0)) for l in range(predicty.shape[0])]
                    if metrics=='Recall':
                        r[i,j,k]=recall_score(testy[:,i,j,k], predicty[:,i,j,k])
                    elif metrics=='Precision':
                        r[i,j,k]=precision_score(testy[:,i,j,k], predicty[:,i,j,k])
                    else:
                        r[i,j,k]=accuracy_score(testy[:,i,j,k], predicty[:,i,j,k])
                    p[i,j,k]=0
                    f1score[i,j,k]=f1_score(testy[:,i,j,k],predicty[:,i,j,k])
                    accuracyscore[i,j,k]=accuracy_score(testy[:,i,j,k],predicty[:,i,j,k])
                    recallscore[i,j,k]=recall_score(testy[:,i,j,k],predicty[:,i,j,k])
                    precisionscore[i,j,k]=precision_score(testy[:,i,j,k],predicty[:,i,j,k])
                elif task_mode=='multi_classify':
                    r[i,j,k]=accuracy_score(testy[:,i,j,:], np.argmax(predicty[:,i,j,:],axis=1))
                    p[i,j,k]=0
    if ifmute == 'no':
        if task_mode=='regression':
            print('相关系数',np.nanmean(r))
        elif task_mode=='binary_classify':
            print('召回率+精确率',np.nanmean(f1score),'准确率',np.nanmean(accuracyscore),'召回率',np.nanmean(recallscore),'精确率',np.nanmean(precisionscore))
        elif task_mode=='multi_classify':
            print('准确率',np.nanmean(r))
    if ifweight=='yes':
        weights=np.zeros((testy.shape[3],testx.shape[3]))
        weight_more=np.zeros((testy.shape[3],testx.shape[3]))
        for i in range(testy.shape[3]):
            for j in range(testx.shape[3]):
                testx_new=copy.deepcopy(testx)
                weight=[]
                for k in range(10):
                    per=np.random.permutation(testx.shape[0])
                    testx_shuffle=testx[per,:,:,j]
                    testx_new[:,:,:,j]=testx_shuffle
                    if k_fold!=None:
                        predicty_new = [model.predict(test_data_generator(testx_new,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0))) for model in models]
                        predicty_new=np.nanmean(predicty_new,axis=0)
                    else:
                        predicty_new = model.predict(test_data_generator(testx_new,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0)))
                    for l in range(testy.shape[1]):
                        for m in range(testy.shape[2]):
                            if task_mode=='regression':
                                weight.append(sklearn.metrics.mean_squared_error(testy[:,l,m,i],predicty_new[:,l,m,i])-sklearn.metrics.mean_squared_error(testy[:,l,m,i],predicty[:,l,m,i]))
                            elif task_mode=='multi_classify':
                                weight.append(sklearn.metrics.log_loss(testy[:,l,m,i],predicty_new[:,l,m,:])-sklearn.metrics.log_loss(testy[:,l,m,i],predicty[:,l,m,:]))
                            else:
                                weight.append(sklearn.metrics.log_loss(testy[:,l,m,i],predicty_new[:,l,m,i])-sklearn.metrics.log_loss(testy[:,l,m,i],predicty[:,l,m,i]))
                weight_more[i,j]=np.nanmean(weight)
        for i in range(testy.shape[3]):
            for j in range(testx.shape[3]):
                weights[i,j]=(weight_more[i,j]/np.nansum(weight_more[i,:]))*100
                print('预报因子',j+1,'对预报值',i+1,'的贡献：',np.array(weights[i,j]),'％')
            print('\n')
    if ifsave=='yes':
        if k_fold!=None:
            for i, model in enumerate(models):
                model.save(savepath+'_'+str(i+1))
        else:
            model.save(savepath)
    if k_fold!=None:
        return models,predicty,testy,r,p,weights
    else:
        return model,predicty,testy,r,p,weights

# %%
model,predicty,testy,r,p,weights=Auto_Unet(CN05_PRE,vx_new,5,3,test_size=0.2,valid_size=None,k_fold=None,task_mode='regression',if_best_mode='no',modelpath=None,ifrandom_split='no',baselayer=16,cov_method='cov',cov_kernelsize=3,cov_strides=1,pool_strides=2,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,activate='tanh',if_last_act='no',if_print_model='yes',loss_function='default',optimizer='Adam',metrics='default',learning_rate=0.0001,epochs=500,batch_size=200,if_early_stopping=200,ifweight='no',ifmute='no',ifsave='yes',savepath=r'E:/xuanxuan/xuanxuan_unet_classify_regress_CN05_morev_sm2_early200',device='gpu')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 143, 247, 1  0           []
#                                 1)]
#
#  conv2d (Conv2D)                (None, 143, 247, 16  1600        ['input_1[0][0]']
#                                 )
#
#  zero_padding2d (ZeroPadding2D)  (None, 143, 247, 16  0          ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 143, 247, 16  2320        ['zero_padding2d[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 143, 247, 16  0          ['conv2d_1[0][0]']
#  D)                             )
#
#  conv2d_2 (Conv2D)              (None, 143, 247, 16  2320        ['zero_padding2d_1[0][0]']
#                                 )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 143, 247, 16  0          ['conv2d_2[0][0]']
#  D)                             )
#
#  max_pooling2d (MaxPooling2D)   (None, 71, 123, 16)  0           ['zero_padding2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 71, 123, 32)  4640        ['max_pooling2d[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 71, 123, 32)  0          ['conv2d_3[0][0]']
#  D)
#
#  conv2d_4 (Conv2D)              (None, 71, 123, 32)  9248        ['zero_padding2d_3[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, 71, 123, 32)  0          ['conv2d_4[0][0]']
#  D)
#
#  conv2d_5 (Conv2D)              (None, 71, 123, 32)  9248        ['zero_padding2d_4[0][0]']
#
#  zero_padding2d_5 (ZeroPadding2  (None, 71, 123, 32)  0          ['conv2d_5[0][0]']
#  D)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 61, 32)  0           ['zero_padding2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 61, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  zero_padding2d_6 (ZeroPadding2  (None, 35, 61, 64)  0           ['conv2d_6[0][0]']
#  D)
#
#  conv2d_7 (Conv2D)              (None, 35, 61, 64)   36928       ['zero_padding2d_6[0][0]']
#
#  zero_padding2d_7 (ZeroPadding2  (None, 35, 61, 64)  0           ['conv2d_7[0][0]']
#  D)
#
#  conv2d_8 (Conv2D)              (None, 35, 61, 64)   36928       ['zero_padding2d_7[0][0]']
#
#  zero_padding2d_8 (ZeroPadding2  (None, 35, 61, 64)  0           ['conv2d_8[0][0]']
#  D)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 30, 64)  0           ['zero_padding2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 17, 30, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  zero_padding2d_9 (ZeroPadding2  (None, 17, 30, 128)  0          ['conv2d_9[0][0]']
#  D)
#
#  conv2d_10 (Conv2D)             (None, 17, 30, 128)  147584      ['zero_padding2d_9[0][0]']
#
#  zero_padding2d_10 (ZeroPadding  (None, 17, 30, 128)  0          ['conv2d_10[0][0]']
#  2D)
#
#  conv2d_11 (Conv2D)             (None, 17, 30, 128)  147584      ['zero_padding2d_10[0][0]']
#
#  zero_padding2d_11 (ZeroPadding  (None, 17, 30, 128)  0          ['conv2d_11[0][0]']
#  2D)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 15, 128)  0           ['zero_padding2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 15, 256)   295168      ['max_pooling2d_3[0][0]']
#
#  zero_padding2d_12 (ZeroPadding  (None, 8, 15, 256)  0           ['conv2d_12[0][0]']
#  2D)
#
#  conv2d_13 (Conv2D)             (None, 8, 15, 256)   590080      ['zero_padding2d_12[0][0]']
#
#  zero_padding2d_13 (ZeroPadding  (None, 8, 15, 256)  0           ['conv2d_13[0][0]']
#  2D)
#
#  conv2d_14 (Conv2D)             (None, 8, 15, 256)   590080      ['zero_padding2d_13[0][0]']
#
#  zero_padding2d_14 (ZeroPadding  (None, 8, 15, 256)  0           ['conv2d_14[0][0]']
#  2D)
#
#  conv2d_15 (Conv2D)             (None, 8, 15, 128)   295040      ['zero_padding2d_14[0][0]']
#
#  zero_padding2d_15 (ZeroPadding  (None, 8, 15, 128)  0           ['conv2d_15[0][0]']
#  2D)
#
#  up_sampling2d (UpSampling2D)   (None, 16, 30, 128)  0           ['zero_padding2d_15[0][0]']
#
#  zero_padding2d_16 (ZeroPadding  (None, 17, 30, 128)  0          ['up_sampling2d[0][0]']
#  2D)
#
#  tf.concat_4 (TFOpLambda)       (None, 17, 30, 256)  0           ['zero_padding2d_16[0][0]',
#                                                                   'zero_padding2d_11[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 17, 30, 128)  295040      ['tf.concat_4[0][0]']
#
#  zero_padding2d_17 (ZeroPadding  (None, 17, 30, 128)  0          ['conv2d_16[0][0]']
#  2D)
#
#  conv2d_17 (Conv2D)             (None, 17, 30, 128)  147584      ['zero_padding2d_17[0][0]']
#
#  zero_padding2d_18 (ZeroPadding  (None, 17, 30, 128)  0          ['conv2d_17[0][0]']
#  2D)
#
#  conv2d_18 (Conv2D)             (None, 17, 30, 128)  147584      ['zero_padding2d_18[0][0]']
#
#  zero_padding2d_19 (ZeroPadding  (None, 17, 30, 128)  0          ['conv2d_18[0][0]']
#  2D)
#
#  conv2d_19 (Conv2D)             (None, 17, 30, 64)   73792       ['zero_padding2d_19[0][0]']
#
#  zero_padding2d_20 (ZeroPadding  (None, 17, 30, 64)  0           ['conv2d_19[0][0]']
#  2D)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 34, 60, 64)  0           ['zero_padding2d_20[0][0]']
#
#  zero_padding2d_21 (ZeroPadding  (None, 35, 61, 64)  0           ['up_sampling2d_1[0][0]']
#  2D)
#
#  tf.concat_5 (TFOpLambda)       (None, 35, 61, 128)  0           ['zero_padding2d_21[0][0]',
#                                                                   'zero_padding2d_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 61, 64)   73792       ['tf.concat_5[0][0]']
#
#  zero_padding2d_22 (ZeroPadding  (None, 35, 61, 64)  0           ['conv2d_20[0][0]']
#  2D)
#
#  conv2d_21 (Conv2D)             (None, 35, 61, 64)   36928       ['zero_padding2d_22[0][0]']
#
#  zero_padding2d_23 (ZeroPadding  (None, 35, 61, 64)  0           ['conv2d_21[0][0]']
#  2D)
#
#  conv2d_22 (Conv2D)             (None, 35, 61, 64)   36928       ['zero_padding2d_23[0][0]']
#
#  zero_padding2d_24 (ZeroPadding  (None, 35, 61, 64)  0           ['conv2d_22[0][0]']
#  2D)
#
#  conv2d_23 (Conv2D)             (None, 35, 61, 32)   18464       ['zero_padding2d_24[0][0]']
#
#  zero_padding2d_25 (ZeroPadding  (None, 35, 61, 32)  0           ['conv2d_23[0][0]']
#  2D)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 70, 122, 32)  0          ['zero_padding2d_25[0][0]']
#
#  zero_padding2d_26 (ZeroPadding  (None, 71, 123, 32)  0          ['up_sampling2d_2[0][0]']
#  2D)
#
#  tf.concat_6 (TFOpLambda)       (None, 71, 123, 64)  0           ['zero_padding2d_26[0][0]',
#                                                                   'zero_padding2d_5[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 71, 123, 32)  18464       ['tf.concat_6[0][0]']
#
#  zero_padding2d_27 (ZeroPadding  (None, 71, 123, 32)  0          ['conv2d_24[0][0]']
#  2D)
#
#  conv2d_25 (Conv2D)             (None, 71, 123, 32)  9248        ['zero_padding2d_27[0][0]']
#
#  zero_padding2d_28 (ZeroPadding  (None, 71, 123, 32)  0          ['conv2d_25[0][0]']
#  2D)
#
#  conv2d_26 (Conv2D)             (None, 71, 123, 32)  9248        ['zero_padding2d_28[0][0]']
#
#  zero_padding2d_29 (ZeroPadding  (None, 71, 123, 32)  0          ['conv2d_26[0][0]']
#  2D)
#
#  conv2d_27 (Conv2D)             (None, 71, 123, 16)  4624        ['zero_padding2d_29[0][0]']
#
#  zero_padding2d_30 (ZeroPadding  (None, 71, 123, 16)  0          ['conv2d_27[0][0]']
#  2D)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 142, 246, 16  0          ['zero_padding2d_30[0][0]']
#                                 )
#
#  zero_padding2d_31 (ZeroPadding  (None, 143, 247, 16  0          ['up_sampling2d_3[0][0]']
#  2D)                            )
#
#  tf.concat_7 (TFOpLambda)       (None, 143, 247, 32  0           ['zero_padding2d_31[0][0]',
#                                 )                                 'zero_padding2d_2[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 143, 247, 16  4624        ['tf.concat_7[0][0]']
#                                 )
#
#  zero_padding2d_32 (ZeroPadding  (None, 143, 247, 16  0          ['conv2d_28[0][0]']
#  2D)                            )
#
#  conv2d_29 (Conv2D)             (None, 143, 247, 16  2320        ['zero_padding2d_32[0][0]']
#                                 )
#
#  zero_padding2d_33 (ZeroPadding  (None, 143, 247, 16  0          ['conv2d_29[0][0]']
#  2D)                            )
#
#  conv2d_30 (Conv2D)             (None, 143, 247, 16  2320        ['zero_padding2d_33[0][0]']
#                                 )
#
#  zero_padding2d_34 (ZeroPadding  (None, 143, 247, 16  0          ['conv2d_30[0][0]']
#  2D)                            )
#
#  conv2d_31 (Conv2D)             (None, 143, 247, 1)  17          ['zero_padding2d_34[0][0]']
#
# ==================================================================================================
# Total params: 3,142,097
# Trainable params: 3,142,097
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/500
# 31/31 [==============================] - 47s 1s/step - loss: 0.3362 - mean_squared_error: 0.3362 - val_loss: 0.3419 - val_mean_squared_error: 0.3419
# Epoch 2/500
# 31/31 [==============================] - 29s 935ms/step - loss: 0.2848 - mean_squared_error: 0.2848 - val_loss: 0.3146 - val_mean_squared_error: 0.3146
# Epoch 3/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.2645 - mean_squared_error: 0.2645 - val_loss: 0.2984 - val_mean_squared_error: 0.2984
# Epoch 4/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.2523 - mean_squared_error: 0.2523 - val_loss: 0.2864 - val_mean_squared_error: 0.2864
# Epoch 5/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.2448 - mean_squared_error: 0.2448 - val_loss: 0.2788 - val_mean_squared_error: 0.2788
# Epoch 6/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.2376 - mean_squared_error: 0.2376 - val_loss: 0.2714 - val_mean_squared_error: 0.2714
# Epoch 7/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.2323 - mean_squared_error: 0.2323 - val_loss: 0.2667 - val_mean_squared_error: 0.2667
# Epoch 8/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 9/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.2236 - mean_squared_error: 0.2236 - val_loss: 0.2592 - val_mean_squared_error: 0.2592
# Epoch 10/500
# 31/31 [==============================] - 30s 963ms/step - loss: 0.2206 - mean_squared_error: 0.2206 - val_loss: 0.2559 - val_mean_squared_error: 0.2559
# Epoch 11/500
# 31/31 [==============================] - 29s 952ms/step - loss: 0.2165 - mean_squared_error: 0.2165 - val_loss: 0.2529 - val_mean_squared_error: 0.2529
# Epoch 12/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.2137 - mean_squared_error: 0.2137 - val_loss: 0.2502 - val_mean_squared_error: 0.2502
# Epoch 13/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.2107 - mean_squared_error: 0.2107 - val_loss: 0.2478 - val_mean_squared_error: 0.2478
# Epoch 14/500
# 31/31 [==============================] - 29s 953ms/step - loss: 0.2073 - mean_squared_error: 0.2073 - val_loss: 0.2459 - val_mean_squared_error: 0.2459
# Epoch 15/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.2091 - mean_squared_error: 0.2091 - val_loss: 0.2440 - val_mean_squared_error: 0.2440
# Epoch 16/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.2056 - mean_squared_error: 0.2056 - val_loss: 0.2435 - val_mean_squared_error: 0.2435
# Epoch 17/500
# 31/31 [==============================] - 29s 938ms/step - loss: 0.2043 - mean_squared_error: 0.2043 - val_loss: 0.2448 - val_mean_squared_error: 0.2448
# Epoch 18/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.2034 - mean_squared_error: 0.2034 - val_loss: 0.2412 - val_mean_squared_error: 0.2412
# Epoch 19/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1982 - mean_squared_error: 0.1982 - val_loss: 0.2386 - val_mean_squared_error: 0.2386
# Epoch 20/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1949 - mean_squared_error: 0.1949 - val_loss: 0.2386 - val_mean_squared_error: 0.2386
# Epoch 21/500
# 31/31 [==============================] - 29s 938ms/step - loss: 0.1934 - mean_squared_error: 0.1934 - val_loss: 0.2367 - val_mean_squared_error: 0.2367
# Epoch 22/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1919 - mean_squared_error: 0.1919 - val_loss: 0.2354 - val_mean_squared_error: 0.2354
# Epoch 23/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1889 - mean_squared_error: 0.1889 - val_loss: 0.2344 - val_mean_squared_error: 0.2344
# Epoch 24/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1856 - mean_squared_error: 0.1856 - val_loss: 0.2336 - val_mean_squared_error: 0.2336
# Epoch 25/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1823 - mean_squared_error: 0.1823 - val_loss: 0.2331 - val_mean_squared_error: 0.2331
# Epoch 26/500
# 31/31 [==============================] - 29s 954ms/step - loss: 0.1813 - mean_squared_error: 0.1813 - val_loss: 0.2329 - val_mean_squared_error: 0.2329
# Epoch 27/500
# 31/31 [==============================] - 29s 941ms/step - loss: 0.1797 - mean_squared_error: 0.1797 - val_loss: 0.2341 - val_mean_squared_error: 0.2341
# Epoch 28/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1776 - mean_squared_error: 0.1776 - val_loss: 0.2358 - val_mean_squared_error: 0.2358
# Epoch 29/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1773 - mean_squared_error: 0.1773 - val_loss: 0.2360 - val_mean_squared_error: 0.2360
# Epoch 30/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1821 - mean_squared_error: 0.1821 - val_loss: 0.2324 - val_mean_squared_error: 0.2324
# Epoch 31/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1772 - mean_squared_error: 0.1772 - val_loss: 0.2343 - val_mean_squared_error: 0.2343
# Epoch 32/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1729 - mean_squared_error: 0.1729 - val_loss: 0.2338 - val_mean_squared_error: 0.2338
# Epoch 33/500
# 31/31 [==============================] - 31s 997ms/step - loss: 0.1709 - mean_squared_error: 0.1709 - val_loss: 0.2355 - val_mean_squared_error: 0.2355
# Epoch 34/500
# 31/31 [==============================] - 30s 957ms/step - loss: 0.1696 - mean_squared_error: 0.1696 - val_loss: 0.2365 - val_mean_squared_error: 0.2365
# Epoch 35/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1706 - mean_squared_error: 0.1706 - val_loss: 0.2356 - val_mean_squared_error: 0.2356
# Epoch 36/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1744 - mean_squared_error: 0.1744 - val_loss: 0.2352 - val_mean_squared_error: 0.2352
# Epoch 37/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1674 - mean_squared_error: 0.1674 - val_loss: 0.2345 - val_mean_squared_error: 0.2345
# Epoch 38/500
# 31/31 [==============================] - 29s 939ms/step - loss: 0.1640 - mean_squared_error: 0.1640 - val_loss: 0.2339 - val_mean_squared_error: 0.2339
# Epoch 39/500
# 31/31 [==============================] - 29s 936ms/step - loss: 0.1618 - mean_squared_error: 0.1618 - val_loss: 0.2346 - val_mean_squared_error: 0.2346
# Epoch 40/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1608 - mean_squared_error: 0.1608 - val_loss: 0.2334 - val_mean_squared_error: 0.2334
# Epoch 41/500
# 31/31 [==============================] - 30s 964ms/step - loss: 0.1604 - mean_squared_error: 0.1604 - val_loss: 0.2325 - val_mean_squared_error: 0.2325
# Epoch 42/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1584 - mean_squared_error: 0.1584 - val_loss: 0.2335 - val_mean_squared_error: 0.2335
# Epoch 43/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1586 - mean_squared_error: 0.1586 - val_loss: 0.2310 - val_mean_squared_error: 0.2310
# Epoch 44/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1575 - mean_squared_error: 0.1575 - val_loss: 0.2309 - val_mean_squared_error: 0.2309
# Epoch 45/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.1570 - mean_squared_error: 0.1570 - val_loss: 0.2324 - val_mean_squared_error: 0.2324
# Epoch 46/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1531 - mean_squared_error: 0.1531 - val_loss: 0.2312 - val_mean_squared_error: 0.2312
# Epoch 47/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1506 - mean_squared_error: 0.1506 - val_loss: 0.2323 - val_mean_squared_error: 0.2323
# Epoch 48/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1506 - mean_squared_error: 0.1506 - val_loss: 0.2316 - val_mean_squared_error: 0.2316
# Epoch 49/500
# 31/31 [==============================] - 29s 954ms/step - loss: 0.1485 - mean_squared_error: 0.1485 - val_loss: 0.2325 - val_mean_squared_error: 0.2325
# Epoch 50/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1513 - mean_squared_error: 0.1513 - val_loss: 0.2303 - val_mean_squared_error: 0.2303
# Epoch 51/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1460 - mean_squared_error: 0.1460 - val_loss: 0.2308 - val_mean_squared_error: 0.2308
# Epoch 52/500
# 31/31 [==============================] - 29s 939ms/step - loss: 0.1455 - mean_squared_error: 0.1455 - val_loss: 0.2325 - val_mean_squared_error: 0.2325
# Epoch 53/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1449 - mean_squared_error: 0.1449 - val_loss: 0.2302 - val_mean_squared_error: 0.2302
# Epoch 54/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1436 - mean_squared_error: 0.1436 - val_loss: 0.2305 - val_mean_squared_error: 0.2305
# Epoch 55/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1466 - mean_squared_error: 0.1466 - val_loss: 0.2349 - val_mean_squared_error: 0.2349
# Epoch 56/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1449 - mean_squared_error: 0.1449 - val_loss: 0.2361 - val_mean_squared_error: 0.2361
# Epoch 57/500
# 31/31 [==============================] - 30s 955ms/step - loss: 0.1404 - mean_squared_error: 0.1404 - val_loss: 0.2350 - val_mean_squared_error: 0.2350
# Epoch 58/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1438 - mean_squared_error: 0.1438 - val_loss: 0.2334 - val_mean_squared_error: 0.2334
# Epoch 59/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1464 - mean_squared_error: 0.1464 - val_loss: 0.2450 - val_mean_squared_error: 0.2450
# Epoch 60/500
# 31/31 [==============================] - 29s 937ms/step - loss: 0.1506 - mean_squared_error: 0.1506 - val_loss: 0.2352 - val_mean_squared_error: 0.2352
# Epoch 61/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1423 - mean_squared_error: 0.1423 - val_loss: 0.2335 - val_mean_squared_error: 0.2335
# Epoch 62/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.1364 - mean_squared_error: 0.1364 - val_loss: 0.2341 - val_mean_squared_error: 0.2341
# Epoch 63/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1349 - mean_squared_error: 0.1349 - val_loss: 0.2385 - val_mean_squared_error: 0.2385
# Epoch 64/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1343 - mean_squared_error: 0.1343 - val_loss: 0.2387 - val_mean_squared_error: 0.2387
# Epoch 65/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1372 - mean_squared_error: 0.1372 - val_loss: 0.2336 - val_mean_squared_error: 0.2336
# Epoch 66/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1355 - mean_squared_error: 0.1355 - val_loss: 0.2319 - val_mean_squared_error: 0.2319
# Epoch 67/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1355 - mean_squared_error: 0.1355 - val_loss: 0.2446 - val_mean_squared_error: 0.2446
# Epoch 68/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1359 - mean_squared_error: 0.1359 - val_loss: 0.2393 - val_mean_squared_error: 0.2393
# Epoch 69/500
# 31/31 [==============================] - 29s 938ms/step - loss: 0.1363 - mean_squared_error: 0.1363 - val_loss: 0.2365 - val_mean_squared_error: 0.2365
# Epoch 70/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1317 - mean_squared_error: 0.1317 - val_loss: 0.2494 - val_mean_squared_error: 0.2494
# Epoch 71/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1313 - mean_squared_error: 0.1313 - val_loss: 0.2490 - val_mean_squared_error: 0.2490
# Epoch 72/500
# 31/31 [==============================] - 29s 933ms/step - loss: 0.1331 - mean_squared_error: 0.1331 - val_loss: 0.2397 - val_mean_squared_error: 0.2397
# Epoch 73/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.1329 - mean_squared_error: 0.1329 - val_loss: 0.2373 - val_mean_squared_error: 0.2373
# Epoch 74/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1326 - mean_squared_error: 0.1326 - val_loss: 0.2539 - val_mean_squared_error: 0.2539
# Epoch 75/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.1347 - mean_squared_error: 0.1347 - val_loss: 0.2444 - val_mean_squared_error: 0.2444
# Epoch 76/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1377 - mean_squared_error: 0.1377 - val_loss: 0.2464 - val_mean_squared_error: 0.2464
# Epoch 77/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.1361 - mean_squared_error: 0.1361 - val_loss: 0.2520 - val_mean_squared_error: 0.2520
# Epoch 78/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1351 - mean_squared_error: 0.1351 - val_loss: 0.2534 - val_mean_squared_error: 0.2534
# Epoch 79/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1349 - mean_squared_error: 0.1349 - val_loss: 0.2413 - val_mean_squared_error: 0.2413
# Epoch 80/500
# 31/31 [==============================] - 29s 937ms/step - loss: 0.1331 - mean_squared_error: 0.1331 - val_loss: 0.2350 - val_mean_squared_error: 0.2350
# Epoch 81/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1344 - mean_squared_error: 0.1344 - val_loss: 0.2414 - val_mean_squared_error: 0.2414
# Epoch 82/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1337 - mean_squared_error: 0.1337 - val_loss: 0.2410 - val_mean_squared_error: 0.2410
# Epoch 83/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1302 - mean_squared_error: 0.1302 - val_loss: 0.2457 - val_mean_squared_error: 0.2457
# Epoch 84/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1258 - mean_squared_error: 0.1258 - val_loss: 0.2460 - val_mean_squared_error: 0.2460
# Epoch 85/500
# 31/31 [==============================] - 29s 939ms/step - loss: 0.1246 - mean_squared_error: 0.1246 - val_loss: 0.2439 - val_mean_squared_error: 0.2439
# Epoch 86/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1268 - mean_squared_error: 0.1268 - val_loss: 0.2391 - val_mean_squared_error: 0.2391
# Epoch 87/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1281 - mean_squared_error: 0.1281 - val_loss: 0.2402 - val_mean_squared_error: 0.2402
# Epoch 88/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1268 - mean_squared_error: 0.1268 - val_loss: 0.2432 - val_mean_squared_error: 0.2432
# Epoch 89/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.1241 - mean_squared_error: 0.1241 - val_loss: 0.2465 - val_mean_squared_error: 0.2465
# Epoch 90/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1232 - mean_squared_error: 0.1232 - val_loss: 0.2517 - val_mean_squared_error: 0.2517
# Epoch 91/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1236 - mean_squared_error: 0.1236 - val_loss: 0.2582 - val_mean_squared_error: 0.2582
# Epoch 92/500
# 31/31 [==============================] - 31s 987ms/step - loss: 0.1268 - mean_squared_error: 0.1268 - val_loss: 0.2518 - val_mean_squared_error: 0.2518
# Epoch 93/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1300 - mean_squared_error: 0.1300 - val_loss: 0.2487 - val_mean_squared_error: 0.2487
# Epoch 94/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1304 - mean_squared_error: 0.1304 - val_loss: 0.2560 - val_mean_squared_error: 0.2560
# Epoch 95/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1312 - mean_squared_error: 0.1312 - val_loss: 0.2578 - val_mean_squared_error: 0.2578
# Epoch 96/500
# 31/31 [==============================] - 29s 938ms/step - loss: 0.1352 - mean_squared_error: 0.1352 - val_loss: 0.2483 - val_mean_squared_error: 0.2483
# Epoch 97/500
# 31/31 [==============================] - 30s 957ms/step - loss: 0.1337 - mean_squared_error: 0.1337 - val_loss: 0.2392 - val_mean_squared_error: 0.2392
# Epoch 98/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1333 - mean_squared_error: 0.1333 - val_loss: 0.2389 - val_mean_squared_error: 0.2389
# Epoch 99/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.1298 - mean_squared_error: 0.1298 - val_loss: 0.2525 - val_mean_squared_error: 0.2525
# Epoch 100/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1224 - mean_squared_error: 0.1224 - val_loss: 0.2497 - val_mean_squared_error: 0.2497
# Epoch 101/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1169 - mean_squared_error: 0.1169 - val_loss: 0.2448 - val_mean_squared_error: 0.2448
# Epoch 102/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1132 - mean_squared_error: 0.1132 - val_loss: 0.2432 - val_mean_squared_error: 0.2432
# Epoch 103/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1111 - mean_squared_error: 0.1111 - val_loss: 0.2424 - val_mean_squared_error: 0.2424
# Epoch 104/500
# 31/31 [==============================] - 29s 953ms/step - loss: 0.1097 - mean_squared_error: 0.1097 - val_loss: 0.2424 - val_mean_squared_error: 0.2424
# Epoch 105/500
# 31/31 [==============================] - 30s 957ms/step - loss: 0.1087 - mean_squared_error: 0.1087 - val_loss: 0.2427 - val_mean_squared_error: 0.2427
# Epoch 106/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1079 - mean_squared_error: 0.1079 - val_loss: 0.2432 - val_mean_squared_error: 0.2432
# Epoch 107/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1073 - mean_squared_error: 0.1073 - val_loss: 0.2440 - val_mean_squared_error: 0.2440
# Epoch 108/500
# 31/31 [==============================] - 29s 952ms/step - loss: 0.1066 - mean_squared_error: 0.1066 - val_loss: 0.2451 - val_mean_squared_error: 0.2451
# Epoch 109/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1061 - mean_squared_error: 0.1061 - val_loss: 0.2464 - val_mean_squared_error: 0.2464
# Epoch 110/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.2480 - val_mean_squared_error: 0.2480
# Epoch 111/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1054 - mean_squared_error: 0.1054 - val_loss: 0.2497 - val_mean_squared_error: 0.2497
# Epoch 112/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1052 - mean_squared_error: 0.1052 - val_loss: 0.2516 - val_mean_squared_error: 0.2516
# Epoch 113/500
# 31/31 [==============================] - 29s 941ms/step - loss: 0.1052 - mean_squared_error: 0.1052 - val_loss: 0.2537 - val_mean_squared_error: 0.2537
# Epoch 114/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1055 - mean_squared_error: 0.1055 - val_loss: 0.2558 - val_mean_squared_error: 0.2558
# Epoch 115/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1062 - mean_squared_error: 0.1062 - val_loss: 0.2576 - val_mean_squared_error: 0.2576
# Epoch 116/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1074 - mean_squared_error: 0.1074 - val_loss: 0.2588 - val_mean_squared_error: 0.2588
# Epoch 117/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1101 - mean_squared_error: 0.1101 - val_loss: 0.2565 - val_mean_squared_error: 0.2565
# Epoch 118/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1138 - mean_squared_error: 0.1138 - val_loss: 0.2557 - val_mean_squared_error: 0.2557
# Epoch 119/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1175 - mean_squared_error: 0.1175 - val_loss: 0.2532 - val_mean_squared_error: 0.2532
# Epoch 120/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1184 - mean_squared_error: 0.1184 - val_loss: 0.2485 - val_mean_squared_error: 0.2485
# Epoch 121/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.1171 - mean_squared_error: 0.1171 - val_loss: 0.2510 - val_mean_squared_error: 0.2510
# Epoch 122/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1166 - mean_squared_error: 0.1166 - val_loss: 0.2713 - val_mean_squared_error: 0.2713
# Epoch 123/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1177 - mean_squared_error: 0.1177 - val_loss: 0.2832 - val_mean_squared_error: 0.2832
# Epoch 124/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.1183 - mean_squared_error: 0.1183 - val_loss: 0.2765 - val_mean_squared_error: 0.2765
# Epoch 125/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1178 - mean_squared_error: 0.1178 - val_loss: 0.2598 - val_mean_squared_error: 0.2598
# Epoch 126/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1127 - mean_squared_error: 0.1127 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 127/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.1086 - mean_squared_error: 0.1086 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 128/500
# 31/31 [==============================] - 29s 952ms/step - loss: 0.1066 - mean_squared_error: 0.1066 - val_loss: 0.2682 - val_mean_squared_error: 0.2682
# Epoch 129/500
# 31/31 [==============================] - 30s 968ms/step - loss: 0.1054 - mean_squared_error: 0.1054 - val_loss: 0.2649 - val_mean_squared_error: 0.2649
# Epoch 130/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.1051 - mean_squared_error: 0.1052 - val_loss: 0.2561 - val_mean_squared_error: 0.2561
# Epoch 131/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1055 - mean_squared_error: 0.1055 - val_loss: 0.2497 - val_mean_squared_error: 0.2497
# Epoch 132/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1065 - mean_squared_error: 0.1065 - val_loss: 0.2505 - val_mean_squared_error: 0.2505
# Epoch 133/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1070 - mean_squared_error: 0.1070 - val_loss: 0.2596 - val_mean_squared_error: 0.2596
# Epoch 134/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1063 - mean_squared_error: 0.1063 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 135/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.2437 - val_mean_squared_error: 0.2437
# Epoch 136/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1042 - mean_squared_error: 0.1042 - val_loss: 0.2404 - val_mean_squared_error: 0.2404
# Epoch 137/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1024 - mean_squared_error: 0.1024 - val_loss: 0.2467 - val_mean_squared_error: 0.2467
# Epoch 138/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1010 - mean_squared_error: 0.1010 - val_loss: 0.2503 - val_mean_squared_error: 0.2503
# Epoch 139/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.0989 - mean_squared_error: 0.0989 - val_loss: 0.2448 - val_mean_squared_error: 0.2448
# Epoch 140/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.0977 - mean_squared_error: 0.0977 - val_loss: 0.2475 - val_mean_squared_error: 0.2475
# Epoch 141/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.0971 - mean_squared_error: 0.0971 - val_loss: 0.2542 - val_mean_squared_error: 0.2542
# Epoch 142/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.0971 - mean_squared_error: 0.0971 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 143/500
# 31/31 [==============================] - 30s 961ms/step - loss: 0.0976 - mean_squared_error: 0.0976 - val_loss: 0.2681 - val_mean_squared_error: 0.2681
# Epoch 144/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.0988 - mean_squared_error: 0.0988 - val_loss: 0.2643 - val_mean_squared_error: 0.2643
# Epoch 145/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0995 - mean_squared_error: 0.0995 - val_loss: 0.2627 - val_mean_squared_error: 0.2627
# Epoch 146/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.1001 - mean_squared_error: 0.1001 - val_loss: 0.2646 - val_mean_squared_error: 0.2646
# Epoch 147/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.1016 - mean_squared_error: 0.1016 - val_loss: 0.2691 - val_mean_squared_error: 0.2691
# Epoch 148/500
# 31/31 [==============================] - 29s 955ms/step - loss: 0.1006 - mean_squared_error: 0.1006 - val_loss: 0.2704 - val_mean_squared_error: 0.2704
# Epoch 149/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0993 - mean_squared_error: 0.0993 - val_loss: 0.2676 - val_mean_squared_error: 0.2676
# Epoch 150/500
# 31/31 [==============================] - 29s 953ms/step - loss: 0.0977 - mean_squared_error: 0.0977 - val_loss: 0.2654 - val_mean_squared_error: 0.2654
# Epoch 151/500
# 31/31 [==============================] - 30s 955ms/step - loss: 0.0966 - mean_squared_error: 0.0966 - val_loss: 0.2639 - val_mean_squared_error: 0.2639
# Epoch 152/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.0969 - mean_squared_error: 0.0969 - val_loss: 0.2683 - val_mean_squared_error: 0.2683
# Epoch 153/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.0976 - mean_squared_error: 0.0976 - val_loss: 0.2718 - val_mean_squared_error: 0.2718
# Epoch 154/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0992 - mean_squared_error: 0.0992 - val_loss: 0.2628 - val_mean_squared_error: 0.2628
# Epoch 155/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1003 - mean_squared_error: 0.1003 - val_loss: 0.2547 - val_mean_squared_error: 0.2547
# Epoch 156/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0996 - mean_squared_error: 0.0996 - val_loss: 0.2499 - val_mean_squared_error: 0.2499
# Epoch 157/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1001 - mean_squared_error: 0.1001 - val_loss: 0.2501 - val_mean_squared_error: 0.2501
# Epoch 158/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1021 - mean_squared_error: 0.1021 - val_loss: 0.2531 - val_mean_squared_error: 0.2531
# Epoch 159/500
# 31/31 [==============================] - 30s 957ms/step - loss: 0.1036 - mean_squared_error: 0.1036 - val_loss: 0.2522 - val_mean_squared_error: 0.2522
# Epoch 160/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1019 - mean_squared_error: 0.1019 - val_loss: 0.2431 - val_mean_squared_error: 0.2431
# Epoch 161/500
# 31/31 [==============================] - 29s 941ms/step - loss: 0.1010 - mean_squared_error: 0.1010 - val_loss: 0.2425 - val_mean_squared_error: 0.2425
# Epoch 162/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.2492 - val_mean_squared_error: 0.2492
# Epoch 163/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1007 - mean_squared_error: 0.1007 - val_loss: 0.2643 - val_mean_squared_error: 0.2643
# Epoch 164/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1005 - mean_squared_error: 0.1005 - val_loss: 0.2736 - val_mean_squared_error: 0.2736
# Epoch 165/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.1000 - mean_squared_error: 0.1000 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
# Epoch 166/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.0974 - mean_squared_error: 0.0974 - val_loss: 0.2545 - val_mean_squared_error: 0.2545
# Epoch 167/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.0961 - mean_squared_error: 0.0961 - val_loss: 0.2565 - val_mean_squared_error: 0.2565
# Epoch 168/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.0958 - mean_squared_error: 0.0958 - val_loss: 0.2528 - val_mean_squared_error: 0.2528
# Epoch 169/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0956 - mean_squared_error: 0.0956 - val_loss: 0.2460 - val_mean_squared_error: 0.2460
# Epoch 170/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0963 - mean_squared_error: 0.0963 - val_loss: 0.2452 - val_mean_squared_error: 0.2452
# Epoch 171/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.0968 - mean_squared_error: 0.0968 - val_loss: 0.2468 - val_mean_squared_error: 0.2468
# Epoch 172/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.0977 - mean_squared_error: 0.0977 - val_loss: 0.2483 - val_mean_squared_error: 0.2483
# Epoch 173/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.0989 - mean_squared_error: 0.0989 - val_loss: 0.2591 - val_mean_squared_error: 0.2591
# Epoch 174/500
# 31/31 [==============================] - 29s 954ms/step - loss: 0.1000 - mean_squared_error: 0.1000 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 175/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1021 - mean_squared_error: 0.1021 - val_loss: 0.2563 - val_mean_squared_error: 0.2563
# Epoch 176/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.1040 - mean_squared_error: 0.1040 - val_loss: 0.2557 - val_mean_squared_error: 0.2557
# Epoch 177/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.1045 - mean_squared_error: 0.1045 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 178/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.1055 - mean_squared_error: 0.1055 - val_loss: 0.2666 - val_mean_squared_error: 0.2666
# Epoch 179/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.1075 - mean_squared_error: 0.1075 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
# Epoch 180/500
# 31/31 [==============================] - 29s 937ms/step - loss: 0.1069 - mean_squared_error: 0.1069 - val_loss: 0.2647 - val_mean_squared_error: 0.2647
# Epoch 181/500
# 31/31 [==============================] - 30s 978ms/step - loss: 0.1074 - mean_squared_error: 0.1074 - val_loss: 0.2699 - val_mean_squared_error: 0.2699
# Epoch 182/500
# 31/31 [==============================] - 29s 954ms/step - loss: 0.1081 - mean_squared_error: 0.1081 - val_loss: 0.2671 - val_mean_squared_error: 0.2671
# Epoch 183/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.1078 - mean_squared_error: 0.1078 - val_loss: 0.2652 - val_mean_squared_error: 0.2652
# Epoch 184/500
# 31/31 [==============================] - 29s 941ms/step - loss: 0.1033 - mean_squared_error: 0.1033 - val_loss: 0.2687 - val_mean_squared_error: 0.2687
# Epoch 185/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.1012 - mean_squared_error: 0.1012 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 186/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0986 - mean_squared_error: 0.0986 - val_loss: 0.2568 - val_mean_squared_error: 0.2568
# Epoch 187/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0942 - mean_squared_error: 0.0942 - val_loss: 0.2552 - val_mean_squared_error: 0.2552
# Epoch 188/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.0901 - mean_squared_error: 0.0901 - val_loss: 0.2546 - val_mean_squared_error: 0.2546
# Epoch 189/500
# 31/31 [==============================] - 29s 954ms/step - loss: 0.0873 - mean_squared_error: 0.0873 - val_loss: 0.2568 - val_mean_squared_error: 0.2568
# Epoch 190/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0855 - mean_squared_error: 0.0855 - val_loss: 0.2593 - val_mean_squared_error: 0.2593
# Epoch 191/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.0842 - mean_squared_error: 0.0842 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 192/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0833 - mean_squared_error: 0.0833 - val_loss: 0.2626 - val_mean_squared_error: 0.2626
# Epoch 193/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0826 - mean_squared_error: 0.0826 - val_loss: 0.2640 - val_mean_squared_error: 0.2640
# Epoch 194/500
# 31/31 [==============================] - 29s 952ms/step - loss: 0.0821 - mean_squared_error: 0.0821 - val_loss: 0.2657 - val_mean_squared_error: 0.2657
# Epoch 195/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0818 - mean_squared_error: 0.0818 - val_loss: 0.2659 - val_mean_squared_error: 0.2659
# Epoch 196/500
# 31/31 [==============================] - 31s 1s/step - loss: 0.0816 - mean_squared_error: 0.0816 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
# Epoch 197/500
# 31/31 [==============================] - 30s 954ms/step - loss: 0.0814 - mean_squared_error: 0.0814 - val_loss: 0.2604 - val_mean_squared_error: 0.2604
# Epoch 198/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0813 - mean_squared_error: 0.0813 - val_loss: 0.2570 - val_mean_squared_error: 0.2570
# Epoch 199/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.0813 - mean_squared_error: 0.0813 - val_loss: 0.2551 - val_mean_squared_error: 0.2551
# Epoch 200/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0814 - mean_squared_error: 0.0814 - val_loss: 0.2547 - val_mean_squared_error: 0.2547
# Epoch 201/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.0815 - mean_squared_error: 0.0815 - val_loss: 0.2543 - val_mean_squared_error: 0.2543
# Epoch 202/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0818 - mean_squared_error: 0.0818 - val_loss: 0.2541 - val_mean_squared_error: 0.2541
# Epoch 203/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0820 - mean_squared_error: 0.0820 - val_loss: 0.2575 - val_mean_squared_error: 0.2575
# Epoch 204/500
# 31/31 [==============================] - 29s 952ms/step - loss: 0.0821 - mean_squared_error: 0.0821 - val_loss: 0.2650 - val_mean_squared_error: 0.2650
# Epoch 205/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0826 - mean_squared_error: 0.0826 - val_loss: 0.2759 - val_mean_squared_error: 0.2759
# Epoch 206/500
# 31/31 [==============================] - 29s 944ms/step - loss: 0.0834 - mean_squared_error: 0.0834 - val_loss: 0.2719 - val_mean_squared_error: 0.2719
# Epoch 207/500
# 31/31 [==============================] - 29s 941ms/step - loss: 0.0835 - mean_squared_error: 0.0835 - val_loss: 0.2649 - val_mean_squared_error: 0.2649
# Epoch 208/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.0832 - mean_squared_error: 0.0832 - val_loss: 0.2663 - val_mean_squared_error: 0.2663
# Epoch 209/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0832 - mean_squared_error: 0.0832 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 210/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0830 - mean_squared_error: 0.0830 - val_loss: 0.2569 - val_mean_squared_error: 0.2569
# Epoch 211/500
# 31/31 [==============================] - 30s 964ms/step - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 212/500
# 31/31 [==============================] - 30s 956ms/step - loss: 0.0838 - mean_squared_error: 0.0838 - val_loss: 0.2599 - val_mean_squared_error: 0.2599
# Epoch 213/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0801 - mean_squared_error: 0.0801 - val_loss: 0.2571 - val_mean_squared_error: 0.2571
# Epoch 214/500
# 31/31 [==============================] - 29s 941ms/step - loss: 0.0799 - mean_squared_error: 0.0799 - val_loss: 0.2543 - val_mean_squared_error: 0.2543
# Epoch 215/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0817 - mean_squared_error: 0.0817 - val_loss: 0.2524 - val_mean_squared_error: 0.2524
# Epoch 216/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0803 - mean_squared_error: 0.0803 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 217/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0807 - mean_squared_error: 0.0807 - val_loss: 0.2676 - val_mean_squared_error: 0.2676
# Epoch 218/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0843 - mean_squared_error: 0.0843 - val_loss: 0.2684 - val_mean_squared_error: 0.2684
# Epoch 219/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0858 - mean_squared_error: 0.0858 - val_loss: 0.2704 - val_mean_squared_error: 0.2704
# Epoch 220/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0901 - mean_squared_error: 0.0901 - val_loss: 0.2839 - val_mean_squared_error: 0.2839
# Epoch 221/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.0971 - mean_squared_error: 0.0971 - val_loss: 0.2918 - val_mean_squared_error: 0.2918
# Epoch 222/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.0981 - mean_squared_error: 0.0981 - val_loss: 0.2626 - val_mean_squared_error: 0.2626
# Epoch 223/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0939 - mean_squared_error: 0.0939 - val_loss: 0.2477 - val_mean_squared_error: 0.2477
# Epoch 224/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.2501 - val_mean_squared_error: 0.2501
# Epoch 225/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0783 - mean_squared_error: 0.0783 - val_loss: 0.2569 - val_mean_squared_error: 0.2569
# Epoch 226/500
# 31/31 [==============================] - 29s 953ms/step - loss: 0.0763 - mean_squared_error: 0.0763 - val_loss: 0.2647 - val_mean_squared_error: 0.2647
# Epoch 227/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.0760 - mean_squared_error: 0.0760 - val_loss: 0.2574 - val_mean_squared_error: 0.2574
# Epoch 228/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.0760 - mean_squared_error: 0.0760 - val_loss: 0.2519 - val_mean_squared_error: 0.2519
# Epoch 229/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0756 - mean_squared_error: 0.0756 - val_loss: 0.2534 - val_mean_squared_error: 0.2534
# Epoch 230/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.0755 - mean_squared_error: 0.0755 - val_loss: 0.2577 - val_mean_squared_error: 0.2577
# Epoch 231/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.0763 - mean_squared_error: 0.0763 - val_loss: 0.2659 - val_mean_squared_error: 0.2659
# Epoch 232/500
# 31/31 [==============================] - 29s 938ms/step - loss: 0.0770 - mean_squared_error: 0.0770 - val_loss: 0.2781 - val_mean_squared_error: 0.2781
# Epoch 233/500
# 31/31 [==============================] - 30s 956ms/step - loss: 0.0782 - mean_squared_error: 0.0782 - val_loss: 0.2734 - val_mean_squared_error: 0.2734
# Epoch 234/500
# 31/31 [==============================] - 29s 949ms/step - loss: 0.0804 - mean_squared_error: 0.0804 - val_loss: 0.2559 - val_mean_squared_error: 0.2559
# Epoch 235/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.0825 - mean_squared_error: 0.0825 - val_loss: 0.2559 - val_mean_squared_error: 0.2559
# Epoch 236/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0816 - mean_squared_error: 0.0816 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 237/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0820 - mean_squared_error: 0.0820 - val_loss: 0.2658 - val_mean_squared_error: 0.2658
# Epoch 238/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0797 - mean_squared_error: 0.0797 - val_loss: 0.2714 - val_mean_squared_error: 0.2714
# Epoch 239/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0774 - mean_squared_error: 0.0774 - val_loss: 0.2546 - val_mean_squared_error: 0.2546
# Epoch 240/500
# 31/31 [==============================] - 29s 948ms/step - loss: 0.0763 - mean_squared_error: 0.0763 - val_loss: 0.2506 - val_mean_squared_error: 0.2506
# Epoch 241/500
# 31/31 [==============================] - 30s 955ms/step - loss: 0.0749 - mean_squared_error: 0.0749 - val_loss: 0.2531 - val_mean_squared_error: 0.2531
# Epoch 242/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0750 - mean_squared_error: 0.0750 - val_loss: 0.2558 - val_mean_squared_error: 0.2558
# Epoch 243/500
# 31/31 [==============================] - 29s 951ms/step - loss: 0.0754 - mean_squared_error: 0.0754 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 244/500
# 31/31 [==============================] - 29s 950ms/step - loss: 0.0753 - mean_squared_error: 0.0753 - val_loss: 0.2631 - val_mean_squared_error: 0.2631
# Epoch 245/500
# 31/31 [==============================] - 29s 940ms/step - loss: 0.0759 - mean_squared_error: 0.0759 - val_loss: 0.2538 - val_mean_squared_error: 0.2538
# Epoch 246/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0766 - mean_squared_error: 0.0766 - val_loss: 0.2505 - val_mean_squared_error: 0.2505
# Epoch 247/500
# 31/31 [==============================] - 29s 946ms/step - loss: 0.0767 - mean_squared_error: 0.0767 - val_loss: 0.2563 - val_mean_squared_error: 0.2563
# Epoch 248/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0773 - mean_squared_error: 0.0773 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 249/500
# 31/31 [==============================] - 29s 942ms/step - loss: 0.0787 - mean_squared_error: 0.0787 - val_loss: 0.2661 - val_mean_squared_error: 0.2661
# Epoch 250/500
# 31/31 [==============================] - 29s 947ms/step - loss: 0.0771 - mean_squared_error: 0.0771 - val_loss: 0.2626 - val_mean_squared_error: 0.2626
# Epoch 251/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.0757 - mean_squared_error: 0.0757 - val_loss: 0.2537 - val_mean_squared_error: 0.2537
# Epoch 252/500
# 31/31 [==============================] - 29s 943ms/step - loss: 0.0740 - mean_squared_error: 0.0740 - val_loss: 0.2487 - val_mean_squared_error: 0.2487
# Epoch 253/500
# 31/31 [==============================] - 29s 945ms/step - loss: 0.0729 - mean_squared_error: 0.0729 - val_loss: 0.2497 - val_mean_squared_error: 0.2497
# 8/8 [==============================] - 3s 296ms/step
# 相关系数 0.3151628191721051
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 32). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: E:/xuanxuan/xuanxuan_unet_classify_regress_CN05_morev_sm2_early200\assets
# INFO:tensorflow:Assets written to: E:/xuanxuan/xuanxuan_unet_classify_regress_CN05_morev_sm2_early200\assets
