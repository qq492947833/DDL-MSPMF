# %%
import Auto_paint_self

# %%
CN05_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\CN05.1_Pre_1961_2021_daily_025x025.nc','pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
CMO_RPH,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\CMORPH_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
ERA5_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\ERA5_China_2001_2022_2.nc','tp','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
td2m,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\2m-dewpoint-temperature-day.nc','d2m','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
t2m,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\2m-temperature-day.nc','t2m','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
sp,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\Surface-pressure-day.nc','sp','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
sm,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\Volumetric-soil-water-layer-1-day.nc','swvl1','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
GPM_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\GPM_China_2001_2022_time.nc','precipitation','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
GSMAP_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\GSMAP_China_2001_2022_time.nc','Pre_daily','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
MSWEP_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\MSWEP_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
PERSIANN_CDR_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\PERSIANN_CDR_PRE_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\xarray\coding\times.py:170: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
import numpy as np
vx=np.zeros((CMO_RPH.shape[0],CMO_RPH.shape[1],CMO_RPH.shape[2],10))
vy=np.zeros((CN05_PRE.shape[0],CN05_PRE.shape[1],CN05_PRE.shape[2]),dtype='int32')
CN05_PRE=CN05_PRE[:,::-1,:]
CN05_PRE=np.nan_to_num(CN05_PRE,nan=0)
vx[:,:,:,0]=CMO_RPH
vx[:,:,:,1]=ERA5_PRE
vx[:,:,:,2]=GPM_PRE
vx[:,:,:,3]=GSMAP_PRE
vx[:,:,:,4]=MSWEP_PRE
vx[:,:,:,5]=PERSIANN_CDR_PRE
vx[:,:,:,6]=td2m
vx[:,:,:,7]=t2m
vx[:,:,:,8]=sp
vx[:,:,:,9]=sm
vx=np.nan_to_num(vx,nan=0)
for i in range(CN05_PRE.shape[1]):
    for j in range(CN05_PRE.shape[2]):
        vy[np.array(CN05_PRE[:,i,j])<0.1,i,j]=0
        vy[np.array(CN05_PRE[:,i,j])>=0.1,i,j]=1

vx=(vx-np.nanmean(vx,axis=0))/np.nanstd(vx,axis=0)
vxs=np.zeros((vx.shape[0]-5,5,vx.shape[1],vx.shape[2],vx.shape[3]))
vys=vy[5:,:,:]
for i in range(vx.shape[0]-5):
    vxs[i,:,:,:,:]=vx[i:i+5,:,:,:]
vxs=(vxs.transpose(0,2,3,1,4))
vxs=vxs.reshape(vxs.shape[0]*vxs.shape[1]*vxs.shape[2],vxs.shape[3],vxs.shape[4])
vys=vys.reshape(vys.shape[0]*vys.shape[1]*vys.shape[2])
vxs=np.nan_to_num(vxs,nan=0)
print(vxs.shape,vys.shape)
CN05_PRE=(CN05_PRE-np.nanmean(CN05_PRE,axis=0))/np.nanstd(CN05_PRE,axis=0)
CN05_PRE=np.nan_to_num(CN05_PRE,nan=0)
CN05_PREs=CN05_PRE[10:,:,:]
CN05_PREs=CN05_PREs.reshape(CN05_PREs.shape[0]*CN05_PREs.shape[1]*CN05_PREs.shape[2])
# Out:
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1484192\3384813512.py:22: RuntimeWarning: invalid value encountered in divide
#   vx=(vx-np.nanmean(vx,axis=0))/np.nanstd(vx,axis=0)
# (270735465, 5, 10) (270735465,)
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1484192\3384813512.py:32: RuntimeWarning: invalid value encountered in divide
#   CN05_PRE=(CN05_PRE-np.nanmean(CN05_PRE,axis=0))/np.nanstd(CN05_PRE,axis=0)

# %%
print(np.isnan(vx).any(),np.isnan(CN05_PRE).any(),np.isnan(vy).any())
# Out:
# True False False

# %%
from keras.models import load_model
import tensorflow as tf
def test_data_generator(x, position, batch_size):
    num_samples = x.shape[0]
    while True:
        indices = np.arange(num_samples)
        for start in range(0, num_samples, batch_size):
            end = min(start + batch_size, num_samples)
            batch_indices = indices[start:end]
            
            x_batch = x[batch_indices]  # 第一个输入特征
            position_batch = position[batch_indices]
            
            yield ({"input_1": x_batch, "input_2": position_batch})
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # 设置只使用 GPU 0
        tf.config.set_visible_devices(gpus[1], 'GPU')
        # 设置 GPU 0 的内存动态增长
        tf.config.experimental.set_memory_growth(gpus[1], True)
    except RuntimeError as e:
        print(e)
vx_position=np.zeros((vxs.shape[0],5))
for i in range(vxs.shape[0]):
    vx_position[i,:]=np.arange(0,5,1)
model=load_model(r'E:/xuanxuan/xuanxuan_transformer_classify_CN05_morev_sm2_lr0.001')
vx_last=model.predict(test_data_generator(vxs,vx_position,100000),steps=(len(vxs) // 100000+(1 if len(vxs) % 100000 != 0 else 0)))
# Out:
# 2708/2708 [==============================] - 296s 109ms/step

# %%
vx_last[vx_last<=0.5]=0
vx_last[vx_last>0.5]=1

# %%
print(vxs.shape)
# Out:
# (270735465, 5, 10)

# %%
vx_last=vx_last.reshape(vx.shape[0]-5,vx.shape[1],vx.shape[2],1)

# %%
vx_new=np.zeros((vx_last.shape[0]-5,vx.shape[1],vx.shape[2],5,11))
vxs=vxs.reshape(vx.shape[0]-5,vx.shape[1],vx.shape[2],5,vx.shape[3])
vx_new[:,:,:,:,:10]=vxs[5:,:,:,:,:]
for i in range(vx_last.shape[0]-5):
    vx_new[i,:,:,:,10]=vx_last[i:i+5,:,:,0].transpose(1,2,0)
vx_new=vx_new.reshape(vx_new.shape[0]*vx_new.shape[1]*vx_new.shape[2],vx_new.shape[3],vx_new.shape[4])

# %%
print(np.isnan(vx_new).any())
# Out:
# False

# %%
print(vx_new.shape,CN05_PREs.shape)
# Out:
# (270558860, 5, 11) (270558860,)

# %%
from keras.models import load_model
index=int((1-0.2)*CN05_PREs.shape[0])
trainy=CN05_PREs[:index]
testy=CN05_PREs[index:]
trainx=vx_new[:index]
testx=vx_new[index:]
test_position=np.zeros((testx.shape[0],testx.shape[1]))
for i in range(testx.shape[0]):
    test_position[i,:]=np.arange(0,5,1)
model=load_model(r'E:/xuanxuan/xuanxuan_transformer_classify_regress_CN05_morev_sm2_lr0.001')
predicty = model.predict(test_data_generator(testx,test_position,100000),steps=(len(testx) // 100000+(1 if len(testx) % 100000 != 0 else 0)))
# Out:
# 542/542 [==============================] - 59s 109ms/step

# %%
print(predicty.shape,testy.shape,CN05_PRE.shape)
# Out:
# (54111772, 1) (54111772,) (7670, 143, 247)

# %%
predicty=predicty.reshape(1532,143,247)
testy=testy.reshape(1532,143,247)

# %%
time=times[-1532:]
print(time.shape)
# Out:
# (1532,)

# %%
CN05_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\CN05.1_Pre_1961_2021_daily_025x025.nc','pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
CN05_PRE=CN05_PRE[:,::-1,:]
lat=lat[::-1]
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\xarray\coding\times.py:170: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
predicty=predicty*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)
testy=testy*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1484192\1497332292.py:1: RuntimeWarning: Mean of empty slice
#   predicty=predicty*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_1484192\1497332292.py:2: RuntimeWarning: Mean of empty slice
#   testy=testy*np.nanstd(CN05_PRE,axis=0)+np.nanmean(CN05_PRE,axis=0)

# %%
Auto_paint_self.create_nc(time,lat,lon,None,predicty,'time','lat','lon','predicty','no',None,'yes','yes','yes','E:/xuanxuan/transformer_pre_predicty_CN05_morev_sm2_lr0.001.nc')
Auto_paint_self.create_nc(time,lat,lon,None,testy,'time','lat','lon','testy','no',None,'yes','yes','yes','E:/xuanxuan/transformer_pre_testy_CN05_morev_sm2_lr0.001.nc')

# %%
r=np.zeros((testy.shape[1],testy.shape[2]))
p=np.zeros((testy.shape[1],testy.shape[2]))
from scipy.stats import pearsonr
for i in range(testy.shape[1]):
    for j in range(testy.shape[2]):
        if np.isnan(CN05_PRE[:,i,j]).any():
            r[i,j],p[i,j]=np.nan,np.nan
        else:
            r[i,j],p[i,j] = pearsonr(predicty[:,i,j],testy[:,i,j])
print(np.nanmean(r))
# Out:
# 0.6616302541952855

# %%
print(np.nanmean(r))
# Out:
# 0.6616302541952855

# %%
#Transformer网络
def Auto_Transformer(vy,vx,timestep,model_list,test_size=0.2,valid_size=0.1,k_fold=None,task_mode='regression',if_best_mode='no',modelpath=None,encoder_deep=1,num_heads=2,key_dim=2,ifdropout='no',trans_dropout_rate=0.0,trans_units=64,trans_activation='sigmoid',embedding_num=None,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,if_print_model='yes',loss_function='default',optimizer='SGD',metrics='default',if_early_stopping=None,learning_rate=0.01,epochs=2000,batch_size=20,ifrandom_split='yes',ifweight='yes',ifmute='no',ifsave='no',savepath=None,device='cpu'):
    import tensorflow as tf
    if device=='gpu':
        gpus = tf.config.list_physical_devices('GPU')
        if gpus:
            try:
                # 设置只使用 GPU 0
                tf.config.set_visible_devices(gpus[1], 'GPU')
                # 设置 GPU 0 的内存动态增长
                tf.config.experimental.set_memory_growth(gpus[1], True)
            except RuntimeError as e:
                print(e)
    else:
        import os
        os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
    from keras.models import Sequential,Model
    from keras.layers import Activation,Dropout,Dense
    from keras.layers import Input,BatchNormalization,LayerNormalization,Embedding,Add,MultiHeadAttention,Flatten
    from keras.initializers import TruncatedNormal,RandomNormal,RandomUniform
    from sklearn.model_selection import train_test_split
    from sklearn.model_selection import KFold
    import numpy as np
    from tensorflow.keras.optimizers import SGD,Adam
    import keras
    from scipy.stats import pearsonr
    import os
    from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
    from keras.models import load_model
    import sklearn
    import copy
    from sklearn.utils.class_weight import compute_class_weight
    from tensorflow.keras import backend as K
    import warnings
    warnings.filterwarnings("ignore")
    
    if embedding_num==None:
        embedding_num=timestep+1
    if task_mode=='regression':
        if loss_function=='default' or loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanSquaredError':
            loss=tf.keras.losses.MeanSquaredError()
        elif loss_function=='MeanAbsoluteError':
            loss=tf.keras.losses.MeanAbsoluteError()
        elif loss_function=='MeanAbsolutePercentageError':
            loss=tf.keras.losses.MeanAbsolutePercentageError()
        elif loss_function=='MeanSquaredLogarithmicError':
            loss=tf.keras.losses.MeanSquaredLogarithmicError()
        elif loss_function=='CosineSimilarity':
            loss=tf.keras.losses.CosineSimilarity()
        elif loss_function=='Huber':
            loss=tf.keras.losses.Huber()
        elif loss_function=='LogCosh':
            loss=tf.keras.losses.LogCosh()
        elif loss_function=='Pearsonr':
            def loss_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            loss=loss_pearsonr
        if metrics=='default' or metrics=='MeanSquaredError':
            metric=tf.keras.metrics.MeanSquaredError()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='MeanAbsolutePercentageError':
            metric=tf.keras.metrics.MeanAbsolutePercentageError()
        elif metrics=='MeanSquaredLogarithmicError':
            metric=tf.keras.metrics.MeanSquaredLogarithmicError()
        elif metrics=='CosineSimilarity':
            metric=tf.keras.metrics.CosineSimilarity()
        elif metrics=='LogCoshError':
            metric=tf.keras.metrics.LogCoshError()
        elif metrics=='Pearsonr':
            def metrics_pearsonr(y_true,y_pred):
                import tensorflow as tf
                y_true_mean=tf.reduce_mean(y_true,axis=0)
                y_pred_mean=tf.reduce_mean(y_pred,axis=0)
                cov=tf.reduce_sum((y_true-y_true_mean)*(y_pred-y_pred_mean),axis=0)
                y_true_v=tf.reduce_sum(tf.square((y_true-y_true_mean)),axis=0)
                y_pred_v=tf.reduce_sum(tf.square((y_pred-y_pred_mean)),axis=0)
                y_true_v=tf.sqrt(y_true_v)
                y_pred_v=tf.sqrt(y_pred_v)
                pearson=cov/(y_true_v*y_pred_v)
                return (1-pearson)**1.5
            metric=metrics_pearsonr
    elif task_mode=='binary_classify':
        if loss_function=='default' or loss_function=='BinaryCrossentropy':
            loss=tf.keras.losses.BinaryCrossentropy()
        elif loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        elif loss_function=='f1':
            def loss_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return 1 - f1
            loss=loss_f1
        if metrics=='default' or metrics=='BinaryAccuracy':
            metric=tf.keras.metrics.BinaryAccuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='BinaryCrossentropy':
            metric=tf.keras.metrics.BinaryCrossentropy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
        elif metrics=='AUC':
            metric=tf.keras.metrics.AUC()
        elif metrics=='Precision':
            metric=tf.keras.metrics.Precision()
        elif metrics=='Recall':
            metric=tf.keras.metrics.Recall()
        elif metrics=='TruePositives':
            metric=tf.keras.metrics.TruePositives()
        elif metrics=='TrueNegatives':
            metric=tf.keras.metrics.TrueNegatives()
        elif metrics=='FalsePositives':
            metric=tf.keras.metrics.FalsePositives()
        elif metrics=='FalseNegatives':
            metric=tf.keras.metrics.FalseNegatives()
        elif metrics=='PrecisionAtRecall':
            metric=tf.keras.metrics.PrecisionAtRecall()
        elif metrics=='SensitivityAtSpecificity':
            metric=tf.keras.metrics.SensitivityAtSpecificity()
        elif metrics=='SpecificityAtSensitivity':
            metric=tf.keras.metrics.SpecificityAtSensitivity()
        elif metrics=='f1':
            def metric_f1(y_true, y_pred):
                y_true = K.cast(y_true, 'float32')
                y_pred = K.cast(y_pred, 'float32')
                
                tp = K.sum(y_true * y_pred)
                fp = K.sum((1 - y_true) * y_pred)
                fn = K.sum(y_true * (1 - y_pred))
                
                precision = tp / (tp + fp + K.epsilon())
                recall = tp / (tp + fn + K.epsilon())
                
                f1 = 2 * precision * recall / (precision + recall + K.epsilon())
                
                return f1
            metric=metric_f1
    elif task_mode=='multi_classify':
        if loss_function=='default' or loss_function=='CategoricalCrossentropy':
            loss=tf.keras.losses.CategoricalCrossentropy()
        elif loss_function=='SparseCategoricalCrossentropy':
            loss=tf.keras.losses.SparseCategoricalCrossentropy()
        elif loss_function=='Poisson':
            loss=tf.keras.losses.Poisson()
        elif loss_function=='KLDivergence':
            loss=tf.keras.losses.KLDivergence()
        if metrics=='default' or metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='MeanAbsoluteError':
            metric=tf.keras.metrics.MeanAbsoluteError()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='TopKCategoricalAccuracy':
            metric=tf.keras.metrics.TopKCategoricalAccuracy()
        elif metrics=='SparseTopKCategoricalAccuracy':
            metric=tf.keras.metrics.SparseTopKCategoricalAccuracy()
        elif metrics=='CategoricalCrossentropy':
            metric=tf.keras.metrics.CategoricalCrossentropy()
        elif metrics=='SparseCategoricalCrossentropy':
            metric=tf.keras.metrics.SparseCategoricalCrossentropy()
        elif metrics=='Accuracy':
            metric=tf.keras.metrics.Accuracy()
        elif metrics=='CategoricalAccuracy':
            metric=tf.keras.metrics.CategoricalAccuracy()
        elif metrics=='SparseCategoricalAccuracy':
            metric=tf.keras.metrics.SparseCategoricalAccuracy()
        elif metrics=='KLDivergence':
            metric=tf.keras.metrics.KLDivergence()
        elif metrics=='Poisson':
            metric=tf.keras.metrics.Poisson()
    weights=0
    model=0
    if vy.ndim==1:
        vy=vy.reshape(vy.shape[0],1)
    if ifrandom_split=='yes':
        trainy,testy,trainx,testx = train_test_split(vy,vx,test_size=test_size,random_state=25)
    else:
        index=int((1-test_size)*vy.shape[0])
        trainy=vy[:index]
        testy=vy[index:]
        trainx=vx[:index,:,:]
        testx=vx[index:,:,:]
    train_position=np.zeros((trainx.shape[0],trainx.shape[1]))
    test_position=np.zeros((testx.shape[0],testx.shape[1]))
    for i in range(trainx.shape[0]):
        train_position[i,:]=np.arange(0,timestep,1)
    for i in range(testx.shape[0]):
        test_position[i,:]=np.arange(0,timestep,1)
    if task_mode!='regression':
        def create_sample_weights_for_batch_multitask(y_batch_multitask, list_of_task_weights_dicts):
            batch_size, num_tasks = y_batch_multitask.shape
            
            if len(list_of_task_weights_dicts) != num_tasks:
                raise ValueError(f"Number of tasks in y_batch_multitask ({num_tasks}) "
                                 f"must match length of list_of_task_weights_dicts ({len(list_of_task_weights_dicts)}).")
        
            sample_weight_batch = np.ones_like(y_batch_multitask, dtype=np.float32)
        
            for i in range(num_tasks):
                task_labels_current_channel = y_batch_multitask[:, i] 
                weights_dict_for_task_i = list_of_task_weights_dicts[i]
                
                weight_for_0 = weights_dict_for_task_i.get(0, 1.0)
                weight_for_1 = weights_dict_for_task_i.get(1, 1.0)
                
                current_task_weights = sample_weight_batch[:, i] 
                current_task_weights[task_labels_current_channel == 0] = weight_for_0
                current_task_weights[task_labels_current_channel == 1] = weight_for_1
                sample_weight_batch[:, i] = current_task_weights
                
            return sample_weight_batch
        def compute_unified_class_weights(y, task_mode=task_mode):
            if task_mode == 'binary_classify':
                if y.ndim == 2 and y.shape[-1] > 1:
                    num_tasks = y.shape[-1]
                    list_of_task_weights_dicts = []
                    possible_binary_classes = np.array([0, 1])
                    for i in range(num_tasks):
                        y_task_i_flat = y[:, i].ravel()
                        if len(y_task_i_flat) == 0:
                            weights_dict_task_i = {0: 1.0, 1: 1.0} 
                        else:
                            valid_labels_mask = np.isin(y_task_i_flat, possible_binary_classes)
                            if not np.all(valid_labels_mask) and np.any(valid_labels_mask): 
                                y_task_i_flat_filtered = y_task_i_flat[valid_labels_mask]
                                if len(y_task_i_flat_filtered) == 0 : y_task_i_flat_filtered = np.array([0]) 
                            elif not np.any(valid_labels_mask): 
                                 y_task_i_flat_filtered = np.array([0]) 
                            else:
                                y_task_i_flat_filtered = y_task_i_flat
                            class_weights_arr = compute_class_weight(
                                class_weight='balanced',
                                classes=possible_binary_classes, 
                                y=y_task_i_flat_filtered
                            )
                            weights_dict_task_i = dict(zip(possible_binary_classes, class_weights_arr))
                        list_of_task_weights_dicts.append(weights_dict_task_i)
                    return list_of_task_weights_dicts 
        
                else: 
                    y_flat = y.ravel()
                    possible_binary_classes = np.array([0, 1])
                    valid_labels_mask = np.isin(y_flat, possible_binary_classes)
                    if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                        y_flat_filtered = y_flat[valid_labels_mask]
                        if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0])
                    elif not np.any(valid_labels_mask):
                         y_flat_filtered = np.array([0])
                    else:
                        y_flat_filtered = y_flat
        
                    class_weights_arr = compute_class_weight(
                        class_weight='balanced',
                        classes=possible_binary_classes,
                        y=y_flat_filtered
                    )
                    return dict(zip(possible_binary_classes, class_weights_arr)) 
        
            elif task_mode == 'multi_classify':
                y_flat = y.ravel()
                possible_multiclass_classes = np.arange(int(np.max(y)+1))
                valid_labels_mask = np.isin(y_flat, possible_multiclass_classes)
                if not np.all(valid_labels_mask) and np.any(valid_labels_mask):
                    y_flat_filtered = y_flat[valid_labels_mask]
                    if len(y_flat_filtered) == 0 : y_flat_filtered = np.array([0]) 
                elif not np.any(valid_labels_mask):
                    y_flat_filtered = np.array([0]) 
                else:
                    y_flat_filtered = y_flat
                class_weights_arr = compute_class_weight(
                    class_weight='balanced',
                    classes=possible_multiclass_classes,
                    y=y_flat_filtered
                )
                return dict(zip(possible_multiclass_classes, class_weights_arr)) 
            else:
                raise ValueError(f"Unsupported task_mode: {task_mode}")
        def create_unified_sample_weights_for_batch(y_batch, unified_class_weights):
            if isinstance(unified_class_weights, list):
                if not (y_batch.ndim == 2 and y_batch.shape[-1] == len(unified_class_weights)):
                     raise ValueError(f"Shape mismatch for multi-task binary weights. "
                                      f"y_batch shape: {y_batch.shape}, num_weight_dicts: {len(unified_class_weights)}")
                return create_sample_weights_for_batch_multitask(y_batch, unified_class_weights)
            elif isinstance(unified_class_weights, dict):
                y_int_labels_for_weights = y_batch
                if y_batch.ndim == 2 and y_batch.shape[-1] == 1: 
                    y_int_labels_for_weights = np.squeeze(y_batch, axis=-1)
                sample_weight_for_batch = np.ones_like(y_int_labels_for_weights, dtype=np.float32)
                for class_label, weight in unified_class_weights.items():
                    sample_weight_for_batch[y_int_labels_for_weights == class_label] = weight
                
                return sample_weight_for_batch
            else:
                raise TypeError(f"unified_class_weights has unexpected type: {type(unified_class_weights)}. Expected dict or list.")
        def train_data_generator(x,position, y, batch_size, task_mode=task_mode):
            num_samples = x.shape[0]
            global_unified_weights = compute_unified_class_weights(y, task_mode)
            while True:
                indices = np.arange(num_samples)
                
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    if len(batch_indices) == 0:
                        continue
        
                    x_batch = x[batch_indices]
                    position_batch = position[batch_indices]
                    y_batch = y[batch_indices] 
                    sample_weight_batch = create_unified_sample_weights_for_batch(
                        y_batch, 
                        global_unified_weights
                    )
                    yield {"input_1": x_batch, "input_2": position_batch}, y_batch, sample_weight_batch
    else:
        def train_data_generator(x, position, y, batch_size):
            num_samples = x.shape[0]
            while True:
                indices = np.arange(num_samples)
                
                for start in range(0, num_samples, batch_size):
                    end = min(start + batch_size, num_samples)
                    batch_indices = indices[start:end]
                    
                    x_batch = x[batch_indices]  
                    position_batch = position[batch_indices]   
                    y_batch = y[batch_indices]      
                    
                    yield ({"input_1": x_batch, "input_2": position_batch}, y_batch)
    def test_data_generator(x, position, batch_size):
        num_samples = x.shape[0]
        while True:
            indices = np.arange(num_samples)
            
            for start in range(0, num_samples, batch_size):
                end = min(start + batch_size, num_samples)
                batch_indices = indices[start:end]
                
                x_batch = x[batch_indices]  # 第一个输入特征
                position_batch = position[batch_indices]
                
                yield ({"input_1": x_batch, "input_2": position_batch})
    if if_best_mode=='no':
        inputshape1=(None,timestep,trainx.shape[2])
        inputshape2=(None,timestep)
        inputs1=Input(shape=(timestep,trainx.shape[2],),name='input_1')
        inputs2=Input(shape=(timestep,),name='input_2')
        for i in range(len(model_list)):
            if model_list[i][0] == 'transformer':
                position_embedding=Embedding(embedding_num,trainx.shape[2],input_length=timestep,input_shape=inputshape2)(inputs2)
                add=Add(input_shape=inputshape1)([inputs1,position_embedding])
                for j in range(encoder_deep):
                    if j ==0:
                        exec('en_multihead'+str(j+1)+'=MultiHeadAttention(num_heads=num_heads,key_dim=key_dim,dropout=trans_dropout_rate,attention_axes=1)(add,add,add)')
                        exec('en_add'+str(j+1)+'=Add()([add,en_multihead'+str(j+1)+'])')
                    else:
                        exec('en_multihead'+str(j+1)+'=MultiHeadAttention(num_heads=num_heads,key_dim=key_dim,dropout=trans_dropout_rate,attention_axes=1)(en_layernormalization'+str(j)+',en_layernormalization'+str(j)+',en_layernormalization'+str(j)+')')
                        exec('en_add'+str(j+1)+'=Add()([en_layernormalization'+str(j)+',en_multihead'+str(j+1)+'])')
                    exec('en_layernormalization'+str(j+1)+'=LayerNormalization()(en_add'+str(j+1)+')')
                    if ifdropout=='yes':
                        exec('en_dropout'+str(j+1)+'=Dropout(trans_dropout_rate)(en_layernormalization'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trans_units,activation=trans_activation)(en_dropout'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trainx.shape[2],activation=trans_activation)(en_fc'+str(j+1)+')')
                    else:
                        exec('en_fc'+str(j+1)+'=Dense(trans_units,activation=trans_activation)(en_layernormalization'+str(j+1)+')')
                        exec('en_fc'+str(j+1)+'=Dense(trainx.shape[2],activation=trans_activation)(en_fc'+str(j+1)+')')
                    exec('en_add'+str(j+1)+'=Add()([en_fc'+str(j+1)+',en_layernormalization'+str(j+1)+'])')
                    exec('en_layernormalization'+str(j+1)+'=LayerNormalization()(en_add'+str(j+1)+')')
                exec('en_fla=Flatten()(en_layernormalization'+str(j+1)+')')
            elif model_list[i][0] == 'batchnormalization':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('BatchNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('BatchNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('BatchNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('BatchNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('BatchNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('BatchNormalization(axis=-1)(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('norm'+str(i+1)+'=BatchNormalization(axis=-1)(fla'+str(i)+')')
            elif model_list[i][0] == 'layernormalization':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('LayerNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('LayerNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('LayerNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('LayerNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('LayerNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('LayerNormalization(axis=-1)(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('norm'+str(i+1)+'=LayerNormalization(axis=-1)(fla'+str(i)+')')
            elif model_list[i][0] == 'activation':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('Activation(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('Activation(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('Activation(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('Activation(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('Activation(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('Activation(model_list[i][1])(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('act'+str(i+1)+'=Activation(model_list[i][1])(fla'+str(i)+')')
            elif model_list[i][0] == 'flatten':
                if model_list[i-1][0]=='transformer':
                    exec('fla'+str(i+1)+'=Flatten()(en_fla)')
                elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                    exec('fla'+str(i+1)+'=Flatten()(norm'+str(i)+')')
                elif model_list[i-1][0]=='activation':
                    exec('fla'+str(i+1)+'=Flatten()(act'+str(i)+')')
                elif model_list[i-1][0]=='dropout':
                    exec('fla'+str(i+1)+'=Flatten()(drop'+str(i)+')')
            elif model_list[i][0] =='fc':
                if if_weight_initialize=='no':
                    if i==len(model_list)-1:
                        if model_list[i-1][0]=='transformer':
                            outputs=eval('Dense(model_list[i][1])(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            outputs=eval('Dense(model_list[i][1])(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            outputs=eval('Dense(model_list[i][1])(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            outputs=eval('Dense(model_list[i][1])(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':
                            outputs=eval('Dense(model_list[i][1])(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            outputs=eval('Dense(model_list[i][1])(fla'+str(i)+')')
                    else:
                        if model_list[i-1][0]=='transformer':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            exec('fc'+str(i+1)+'=Dense(model_list[i][1])(fla'+str(i)+')')
                else:
                    if i==len(model_list)-1:
                        if model_list[i-1][0]=='transformer':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':   
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            if weight_initialize_method=='RandomNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                outputs=eval('Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                    else:
                        if model_list[i-1][0]=='transformer':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(en_fla)')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(en_fla)')
                        elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(norm'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(norm'+str(i)+')')
                        elif model_list[i-1][0]=='activation':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(act'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(act'+str(i)+')')
                        elif model_list[i-1][0]=='dropout':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(drop'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(drop'+str(i)+')')
                        elif model_list[i-1][0]=='fc':   
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fc'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fc'+str(i)+')')
                        elif model_list[i-1][0]=='flatten':
                            if weight_initialize_method=='RandomNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='RandomUniform':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = RandomUniform(minval=weight_initialize_parameter1,maxval=weight_initialize_parameter2))(fla'+str(i)+')')
                            elif weight_initialize_method=='TruncatedNormal':
                                exec('fc'+str(i+1)+'=Dense(model_list[i][1],kernel_initializer = TruncatedNormal(mean=weight_initialize_parameter1,stddev=weight_initialize_parameter2))(fla'+str(i)+')')
            elif model_list[i][0] == 'dropout':
                if i==len(model_list)-1:
                    if model_list[i-1][0]=='transformer':
                        outputs=eval('Dropout(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        outputs=eval('Dropout(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        outputs=eval('Dropout(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        outputs=eval('Dropout(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        outputs=eval('Dropout(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        outputs=eval('Dropout(model_list[i][1])(fla'+str(i)+')')
                else:
                    if model_list[i-1][0]=='transformer':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(en_fla)')
                    elif model_list[i-1][0]=='batchnormalization' or model_list[i-1][0]=='layernormalization':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(norm'+str(i)+')')
                    elif model_list[i-1][0]=='activation':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(act'+str(i)+')')
                    elif model_list[i-1][0]=='dropout' :
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(drop'+str(i)+')')
                    elif model_list[i-1][0]=='fc':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(fc'+str(i)+')')
                    elif model_list[i-1][0]=='flatten':
                        exec('drop'+str(i+1)+'=Dropout(model_list[i][1])(fla'+str(i)+')')
        model=eval('Model(inputs=[inputs1,inputs2], outputs=outputs)')
        if optimizer == 'SGD':
            opt = SGD(lr = learning_rate)
        elif optimizer == 'Adam':
            opt = Adam(lr = learning_rate)
        model.compile(loss=loss,optimizer=opt,metrics=[metric])
    elif if_best_mode=='yes' or if_best_mode=='load':
        if k_fold!=None:
            models=[]
            for i in range(k_fold):
                models.append(load_model(modelpath+'_'+str(i+1)))
        else:
            model=load_model(modelpath)
    if if_print_model=='yes':
        if k_fold!=None:
            if if_best_mode=='yes' or if_best_mode=='load':
                print(models[0].summary())
            else:
                print(model.summary())
        else:
            print(model.summary())
    if epochs!=0:
        if valid_size!=None or k_fold !=None:
            if k_fold!=None:
                if if_best_mode=='no' :
                    models = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold, position_train_fold = trainx[train_idx], trainy[train_idx], train_position[train_idx]
                        X_val_fold, y_val_fold, position_val_fold = trainx[val_idx], trainy[val_idx], train_position[val_idx]
                        model=eval('Model(inputs=[inputs1,inputs2], outputs=outputs)')
                        model.compile(loss=loss,optimizer=opt,metrics=[metric])
                        if if_early_stopping!=None:
                            H = model.fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = model.fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models.append(model)
                else:
                    models_new = []
                    if ifrandom_split=='yes':
                        kf = KFold(n_splits=k_fold, shuffle=True, random_state=25)
                    else:
                        kf = KFold(n_splits=k_fold, shuffle=False)
                    for fold_no, (train_idx, val_idx) in enumerate(kf.split(trainx, trainy)):
                        X_train_fold, y_train_fold, position_train_fold = trainx[train_idx], trainy[train_idx], train_position[train_idx]
                        X_val_fold, y_val_fold, position_val_fold = trainx[val_idx], trainy[val_idx], train_position[val_idx]
                        if if_early_stopping!=None:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                        else:
                            H = models[fold_no].fit(train_data_generator(X_train_fold,position_train_fold,y_train_fold,batch_size),steps_per_epoch=(len(X_train_fold) // batch_size+(1 if len(X_train_fold) % batch_size != 0 else 0)),validation_data=train_data_generator(X_val_fold,position_val_fold,y_val_fold,batch_size),validation_steps=(len(X_val_fold) // batch_size+(1 if len(X_val_fold) % batch_size != 0 else 0)),epochs = epochs)
                        models_new.append(models[fold_no])
                    models=models_new
            else:
                if ifrandom_split=='yes':
                    trainy,validy,trainx,validx,train_position,valid_position = train_test_split(trainy,trainx,train_position,test_size=valid_size/(1-test_size),random_state=25)
                else:
                    index=int((1-valid_size/(1-test_size))*trainy.shape[0])
                    validy=trainy[index:]
                    trainy=trainy[:index]
                    validx=trainx[index:]
                    trainx=trainx[:index]
                    valid_position=train_position[index:]
                    train_position=train_position[:index]
                if if_early_stopping!=None:
                    H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,valid_position,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
                else:
                    H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(validx,valid_position,validy,batch_size),validation_steps=(len(validx) // batch_size+(1 if len(validx) % batch_size != 0 else 0)),epochs = epochs)
        else:
            if if_early_stopping!=None:
                H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,test_position,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=if_early_stopping,restore_best_weights=True)])
            else:
                H = model.fit(train_data_generator(trainx,train_position,trainy,batch_size),steps_per_epoch=(len(trainx) // batch_size+(1 if len(trainx) % batch_size != 0 else 0)),validation_data=train_data_generator(testx,test_position,testy,batch_size),validation_steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)),epochs = epochs)
    if k_fold!=None:
        predicty = [model.predict(test_data_generator(testx,test_position,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0))) for model in models]
        predicty=np.nanmean(predicty,axis=0)
    else:
        predicty = model.predict(test_data_generator(testx,test_position,batch_size),steps=(len(testx) // batch_size+(1 if len(testx) % batch_size != 0 else 0)))
    predicty = np.nan_to_num(predicty,nan=0)
    if task_mode=='regression':
        r=np.zeros((testy.shape[1]))
        p=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            r[i],p[i] = pearsonr(predicty[:,i],testy[:,i])
            r=np.nan_to_num(r,nan=0)
    elif task_mode=='binary_classify':
        accuracy=np.zeros((testy.shape[1]))
        recall=np.zeros((testy.shape[1]))
        precision=np.zeros((testy.shape[1]))
        f1=np.zeros((testy.shape[1]))
        for i in range(predicty.shape[1]):
            predicty[:,i]=[int(round(predicty[j,i],0)) for j in range(predicty.shape[0])]
        r=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            if metrics=='Recall':
                r[i]=recall_score(testy[:,i], predicty[:,i])
            elif metrics=='Precision':
                r[i]=precision_score(testy[:,i], predicty[:,i])
            else:
                r[i]=accuracy_score(testy[:,i], predicty[:,i])
            recall[i]=recall_score(testy[:,i], predicty[:,i])
            precision[i]=precision_score(testy[:,i], predicty[:,i])
            accuracy[i]=accuracy_score(testy[:,i], predicty[:,i])
            f1[i]=f1_score(testy[:,i], predicty[:,i])
        p=0
    elif task_mode=='multi_classify':
        r=np.zeros((testy.shape[1]))
        for i in range(testy.shape[1]):
            r[i]=accuracy_score(testy[:,i], np.argmax(predicty,axis=1))
        p=0
    if ifmute == 'no':
        if task_mode=='regression':
            print('相关系数',np.nanmean(r))
        elif task_mode=='binary_classify':
            print('召回率+精确率',np.nanmean(f1),'准确率',np.nanmean(accuracy),'召回率',np.nanmean(recall),'精确率',np.nanmean(precision))
        elif task_mode=='multi_classify':
            print('准确率',np.nanmean(r))
    if ifweight=='yes':
        weights=np.zeros((testy.shape[1],testx.shape[2]))
        weight_more=np.zeros((testy.shape[1],testx.shape[2]))
        for i in range(testy.shape[1]):
            for j in range(testx.shape[2]):
                testx_new=copy.deepcopy(testx)
                weight=[]
                for k in range(10):
                    per=np.random.permutation(testx.shape[0])
                    testx_shuffle=testx[per,:,j]
                    testx_new[:,:,j]=testx_shuffle
                    if k_fold!=None:
                        predicty_new = [model.predict(test_data_generator(testx_new,test_position,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0))) for model in models]
                        predicty_new=np.nanmean(predicty_new,axis=0)
                    else:
                        predicty_new = model.predict(test_data_generator(testx_new,test_position,batch_size),steps=(len(testx_new) // batch_size+(1 if len(testx_new) % batch_size != 0 else 0)))
                    if task_mode=='regression':
                        weight.append(sklearn.metrics.mean_squared_error(testy[:,i],predicty_new[:,i])-sklearn.metrics.mean_squared_error(testy[:,i],predicty[:,i]))
                    elif task_mode=='multi_classify':
                        weight.append(sklearn.metrics.log_loss(testy[:,i],predicty_new[:,:])-sklearn.metrics.log_loss(testy[:,i],predicty[:,:]))
                    else:
                        weight.append(sklearn.metrics.log_loss(testy[:,i],predicty_new[:,i])-sklearn.metrics.log_loss(testy[:,i],predicty[:,i]))
                weight_more[i,j]=np.nanmean(weight)
        for i in range(testy.shape[1]):
            for j in range(testx.shape[2]):
                weights[i,j]=(weight_more[i,j]/np.nansum(weight_more[i,:]))*100
                print('预报因子',j+1,'对预报值',i+1,'的贡献：',np.array(weights[i,j]),'％')
            print('\n')
    if ifsave=='yes':
        if k_fold!=None:
            for i, model in enumerate(models):
                model.save(savepath+'_'+str(i+1))
        else:
            model.save(savepath)
    if k_fold!=None:
        return models,predicty,testy,r,p,weights
    else:
        return model,predicty,testy,r,p,weights

# %%
model,predicty,testy,r,p,weights=Auto_Transformer(CN05_PREs,vx_new,5,[['transformer'],['fc',1024],['activation','tanh'],['fc',1]],test_size=0.2,valid_size=None,k_fold=None,task_mode='regression',if_best_mode='no',modelpath=None,encoder_deep=2,num_heads=2,key_dim=2,ifdropout='no',trans_dropout_rate=0.0,trans_units=1024,trans_activation='tanh',embedding_num=None,if_weight_initialize='no',weight_initialize_method='TruncatedNormal',weight_initialize_parameter1=0.00,weight_initialize_parameter2=0.05,if_print_model='yes',loss_function='default',optimizer='Adam',metrics='default',learning_rate=0.001,epochs=500,batch_size=100000,ifrandom_split='no',ifweight='no',ifmute='no',ifsave='yes',savepath=r'E:/xuanxuan/xuanxuan_transformer_classify_regress_CN05_morev_sm2_lr0.001',device='gpu')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5)]          0           []
#
#  input_1 (InputLayer)           [(None, 5, 11)]      0           []
#
#  embedding (Embedding)          (None, 5, 11)        66          ['input_2[0][0]']
#
#  add (Add)                      (None, 5, 11)        0           ['input_1[0][0]',
#                                                                   'embedding[0][0]']
#
#  multi_head_attention (MultiHea  (None, 5, 11)       199         ['add[0][0]',
#  dAttention)                                                      'add[0][0]',
#                                                                   'add[0][0]']
#
#  add_1 (Add)                    (None, 5, 11)        0           ['add[0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 5, 11)       22          ['add_1[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 5, 1024)      12288       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 5, 11)        11275       ['dense[0][0]']
#
#  add_2 (Add)                    (None, 5, 11)        0           ['dense_1[0][0]',
#                                                                   'layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 5, 11)       22          ['add_2[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 5, 11)       199         ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]',
#                                                                   'layer_normalization_1[0][0]']
#
#  add_3 (Add)                    (None, 5, 11)        0           ['layer_normalization_1[0][0]',
#                                                                   'multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 5, 11)       22          ['add_3[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 5, 1024)      12288       ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 5, 11)        11275       ['dense_2[0][0]']
#
#  add_4 (Add)                    (None, 5, 11)        0           ['dense_3[0][0]',
#                                                                   'layer_normalization_2[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 5, 11)       22          ['add_4[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 55)           0           ['layer_normalization_3[0][0]']
#
#  dense_4 (Dense)                (None, 1024)         57344       ['flatten[0][0]']
#
#  activation (Activation)        (None, 1024)         0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 1)            1025        ['activation[0][0]']
#
# ==================================================================================================
# Total params: 106,047
# Trainable params: 106,047
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/500
# 2165/2165 [==============================] - 642s 294ms/step - loss: 0.2888 - mean_squared_error: 0.2888 - val_loss: 0.3133 - val_mean_squared_error: 0.3133
# Epoch 2/500
# 2165/2165 [==============================] - 654s 302ms/step - loss: 0.2570 - mean_squared_error: 0.2570 - val_loss: 0.2963 - val_mean_squared_error: 0.2963
# Epoch 3/500
# 2165/2165 [==============================] - 650s 300ms/step - loss: 0.2521 - mean_squared_error: 0.2521 - val_loss: 0.2900 - val_mean_squared_error: 0.2900
# Epoch 4/500
# 2165/2165 [==============================] - 649s 300ms/step - loss: 0.2496 - mean_squared_error: 0.2496 - val_loss: 0.2907 - val_mean_squared_error: 0.2907
# Epoch 5/500
# 2165/2165 [==============================] - 647s 299ms/step - loss: 0.2477 - mean_squared_error: 0.2477 - val_loss: 0.2872 - val_mean_squared_error: 0.2872
# Epoch 6/500
# 2165/2165 [==============================] - 644s 298ms/step - loss: 0.2461 - mean_squared_error: 0.2461 - val_loss: 0.2865 - val_mean_squared_error: 0.2865
# Epoch 7/500
# 2165/2165 [==============================] - 667s 308ms/step - loss: 0.2448 - mean_squared_error: 0.2448 - val_loss: 0.2855 - val_mean_squared_error: 0.2855
# Epoch 8/500
# 2165/2165 [==============================] - 666s 308ms/step - loss: 0.2437 - mean_squared_error: 0.2437 - val_loss: 0.2819 - val_mean_squared_error: 0.2819
# Epoch 9/500
# 2165/2165 [==============================] - 673s 311ms/step - loss: 0.2426 - mean_squared_error: 0.2426 - val_loss: 0.2767 - val_mean_squared_error: 0.2767
# Epoch 10/500
# 2165/2165 [==============================] - 797s 368ms/step - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2738 - val_mean_squared_error: 0.2738
# Epoch 11/500
# 2165/2165 [==============================] - 739s 341ms/step - loss: 0.2409 - mean_squared_error: 0.2409 - val_loss: 0.2739 - val_mean_squared_error: 0.2739
# Epoch 12/500
# 2165/2165 [==============================] - 714s 330ms/step - loss: 0.2402 - mean_squared_error: 0.2402 - val_loss: 0.2704 - val_mean_squared_error: 0.2704
# Epoch 13/500
# 2165/2165 [==============================] - 686s 317ms/step - loss: 0.2395 - mean_squared_error: 0.2395 - val_loss: 0.2691 - val_mean_squared_error: 0.2691
# Epoch 14/500
# 2165/2165 [==============================] - 641s 296ms/step - loss: 0.2387 - mean_squared_error: 0.2387 - val_loss: 0.2687 - val_mean_squared_error: 0.2687
# Epoch 15/500
# 2165/2165 [==============================] - 656s 303ms/step - loss: 0.2381 - mean_squared_error: 0.2381 - val_loss: 0.2682 - val_mean_squared_error: 0.2682
# Epoch 16/500
# 2165/2165 [==============================] - 641s 296ms/step - loss: 0.2376 - mean_squared_error: 0.2376 - val_loss: 0.2682 - val_mean_squared_error: 0.2682
# Epoch 17/500
# 2165/2165 [==============================] - 634s 293ms/step - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2679 - val_mean_squared_error: 0.2679
# Epoch 18/500
# 2165/2165 [==============================] - 646s 298ms/step - loss: 0.2367 - mean_squared_error: 0.2367 - val_loss: 0.2676 - val_mean_squared_error: 0.2676
# Epoch 19/500
# 2165/2165 [==============================] - 695s 321ms/step - loss: 0.2363 - mean_squared_error: 0.2363 - val_loss: 0.2682 - val_mean_squared_error: 0.2682
# Epoch 20/500
# 2165/2165 [==============================] - 633s 292ms/step - loss: 0.2360 - mean_squared_error: 0.2360 - val_loss: 0.2684 - val_mean_squared_error: 0.2684
# Epoch 21/500
# 2165/2165 [==============================] - 676s 312ms/step - loss: 0.2357 - mean_squared_error: 0.2357 - val_loss: 0.2680 - val_mean_squared_error: 0.2680
# Epoch 22/500
# 2165/2165 [==============================] - 829s 383ms/step - loss: 0.2353 - mean_squared_error: 0.2353 - val_loss: 0.2678 - val_mean_squared_error: 0.2678
# Epoch 23/500
# 2165/2165 [==============================] - 911s 421ms/step - loss: 0.2351 - mean_squared_error: 0.2351 - val_loss: 0.2683 - val_mean_squared_error: 0.2683
# Epoch 24/500
# 2165/2165 [==============================] - 895s 414ms/step - loss: 0.2348 - mean_squared_error: 0.2348 - val_loss: 0.2672 - val_mean_squared_error: 0.2672
# Epoch 25/500
# 2165/2165 [==============================] - 899s 415ms/step - loss: 0.2345 - mean_squared_error: 0.2345 - val_loss: 0.2676 - val_mean_squared_error: 0.2676
# Epoch 26/500
# 2165/2165 [==============================] - 993s 459ms/step - loss: 0.2342 - mean_squared_error: 0.2342 - val_loss: 0.2676 - val_mean_squared_error: 0.2676
# Epoch 27/500
# 2165/2165 [==============================] - 974s 450ms/step - loss: 0.2340 - mean_squared_error: 0.2340 - val_loss: 0.2677 - val_mean_squared_error: 0.2677
# Epoch 28/500
# 2165/2165 [==============================] - 1020s 471ms/step - loss: 0.2338 - mean_squared_error: 0.2338 - val_loss: 0.2670 - val_mean_squared_error: 0.2670
# Epoch 29/500
# 2165/2165 [==============================] - 1000s 462ms/step - loss: 0.2335 - mean_squared_error: 0.2335 - val_loss: 0.2669 - val_mean_squared_error: 0.2669
# Epoch 30/500
# 2165/2165 [==============================] - 938s 433ms/step - loss: 0.2332 - mean_squared_error: 0.2332 - val_loss: 0.2669 - val_mean_squared_error: 0.2669
# Epoch 31/500
# 2165/2165 [==============================] - 882s 407ms/step - loss: 0.2331 - mean_squared_error: 0.2331 - val_loss: 0.2670 - val_mean_squared_error: 0.2670
# Epoch 32/500
# 2165/2165 [==============================] - 873s 403ms/step - loss: 0.2328 - mean_squared_error: 0.2328 - val_loss: 0.2670 - val_mean_squared_error: 0.2670
# Epoch 33/500
# 2165/2165 [==============================] - 871s 402ms/step - loss: 0.2326 - mean_squared_error: 0.2326 - val_loss: 0.2657 - val_mean_squared_error: 0.2657
# Epoch 34/500
# 2165/2165 [==============================] - 875s 404ms/step - loss: 0.2325 - mean_squared_error: 0.2325 - val_loss: 0.2657 - val_mean_squared_error: 0.2657
# Epoch 35/500
# 2165/2165 [==============================] - 865s 399ms/step - loss: 0.2323 - mean_squared_error: 0.2323 - val_loss: 0.2658 - val_mean_squared_error: 0.2658
# Epoch 36/500
# 2165/2165 [==============================] - 877s 405ms/step - loss: 0.2321 - mean_squared_error: 0.2321 - val_loss: 0.2656 - val_mean_squared_error: 0.2656
# Epoch 37/500
# 2165/2165 [==============================] - 956s 441ms/step - loss: 0.2320 - mean_squared_error: 0.2320 - val_loss: 0.2654 - val_mean_squared_error: 0.2654
# Epoch 38/500
# 2165/2165 [==============================] - 1192s 551ms/step - loss: 0.2318 - mean_squared_error: 0.2318 - val_loss: 0.2651 - val_mean_squared_error: 0.2651
# Epoch 39/500
# 2165/2165 [==============================] - 1090s 503ms/step - loss: 0.2317 - mean_squared_error: 0.2317 - val_loss: 0.2646 - val_mean_squared_error: 0.2646
# Epoch 40/500
# 2165/2165 [==============================] - 1004s 464ms/step - loss: 0.2315 - mean_squared_error: 0.2315 - val_loss: 0.2642 - val_mean_squared_error: 0.2642
# Epoch 41/500
# 2165/2165 [==============================] - 986s 456ms/step - loss: 0.2314 - mean_squared_error: 0.2314 - val_loss: 0.2644 - val_mean_squared_error: 0.2644
# Epoch 42/500
# 2165/2165 [==============================] - 951s 439ms/step - loss: 0.2313 - mean_squared_error: 0.2313 - val_loss: 0.2642 - val_mean_squared_error: 0.2642
# Epoch 43/500
# 2165/2165 [==============================] - 983s 454ms/step - loss: 0.2311 - mean_squared_error: 0.2311 - val_loss: 0.2646 - val_mean_squared_error: 0.2646
# Epoch 44/500
# 2165/2165 [==============================] - 932s 430ms/step - loss: 0.2311 - mean_squared_error: 0.2311 - val_loss: 0.2639 - val_mean_squared_error: 0.2639
# Epoch 45/500
# 2165/2165 [==============================] - 941s 435ms/step - loss: 0.2309 - mean_squared_error: 0.2309 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
# Epoch 46/500
# 2165/2165 [==============================] - 931s 430ms/step - loss: 0.2308 - mean_squared_error: 0.2308 - val_loss: 0.2639 - val_mean_squared_error: 0.2639
# Epoch 47/500
# 2165/2165 [==============================] - 970s 448ms/step - loss: 0.2308 - mean_squared_error: 0.2308 - val_loss: 0.2636 - val_mean_squared_error: 0.2636
# Epoch 48/500
# 2165/2165 [==============================] - 946s 437ms/step - loss: 0.2306 - mean_squared_error: 0.2306 - val_loss: 0.2635 - val_mean_squared_error: 0.2635
# Epoch 49/500
# 2165/2165 [==============================] - 912s 421ms/step - loss: 0.2306 - mean_squared_error: 0.2306 - val_loss: 0.2632 - val_mean_squared_error: 0.2632
# Epoch 50/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2305 - mean_squared_error: 0.2305 - val_loss: 0.2634 - val_mean_squared_error: 0.2634
# Epoch 51/500
# 2165/2165 [==============================] - 976s 451ms/step - loss: 0.2304 - mean_squared_error: 0.2304 - val_loss: 0.2633 - val_mean_squared_error: 0.2633
# Epoch 52/500
# 2165/2165 [==============================] - 1017s 470ms/step - loss: 0.2303 - mean_squared_error: 0.2303 - val_loss: 0.2632 - val_mean_squared_error: 0.2632
# Epoch 53/500
# 2165/2165 [==============================] - 931s 430ms/step - loss: 0.2302 - mean_squared_error: 0.2302 - val_loss: 0.2634 - val_mean_squared_error: 0.2634
# Epoch 54/500
# 2165/2165 [==============================] - 947s 438ms/step - loss: 0.2301 - mean_squared_error: 0.2301 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 55/500
# 2165/2165 [==============================] - 965s 446ms/step - loss: 0.2300 - mean_squared_error: 0.2300 - val_loss: 0.2636 - val_mean_squared_error: 0.2636
# Epoch 56/500
# 2165/2165 [==============================] - 1044s 482ms/step - loss: 0.2300 - mean_squared_error: 0.2300 - val_loss: 0.2636 - val_mean_squared_error: 0.2636
# Epoch 57/500
# 2165/2165 [==============================] - 1097s 507ms/step - loss: 0.2299 - mean_squared_error: 0.2299 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
# Epoch 58/500
# 2165/2165 [==============================] - 1144s 529ms/step - loss: 0.2298 - mean_squared_error: 0.2298 - val_loss: 0.2639 - val_mean_squared_error: 0.2639
# Epoch 59/500
# 2165/2165 [==============================] - 1153s 532ms/step - loss: 0.2298 - mean_squared_error: 0.2298 - val_loss: 0.2635 - val_mean_squared_error: 0.2635
# Epoch 60/500
# 2165/2165 [==============================] - 1026s 474ms/step - loss: 0.2297 - mean_squared_error: 0.2297 - val_loss: 0.2641 - val_mean_squared_error: 0.2641
# Epoch 61/500
# 2165/2165 [==============================] - 965s 446ms/step - loss: 0.2296 - mean_squared_error: 0.2296 - val_loss: 0.2639 - val_mean_squared_error: 0.2639
# Epoch 62/500
# 2165/2165 [==============================] - 972s 449ms/step - loss: 0.2295 - mean_squared_error: 0.2295 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 63/500
# 2165/2165 [==============================] - 1003s 463ms/step - loss: 0.2295 - mean_squared_error: 0.2295 - val_loss: 0.2639 - val_mean_squared_error: 0.2639
# Epoch 64/500
# 2165/2165 [==============================] - 968s 447ms/step - loss: 0.2294 - mean_squared_error: 0.2294 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
# Epoch 65/500
# 2165/2165 [==============================] - 1028s 475ms/step - loss: 0.2293 - mean_squared_error: 0.2293 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 66/500
# 2165/2165 [==============================] - 1033s 477ms/step - loss: 0.2293 - mean_squared_error: 0.2293 - val_loss: 0.2642 - val_mean_squared_error: 0.2642
# Epoch 67/500
# 2165/2165 [==============================] - 1146s 530ms/step - loss: 0.2292 - mean_squared_error: 0.2292 - val_loss: 0.2638 - val_mean_squared_error: 0.2638
# Epoch 68/500
# 2165/2165 [==============================] - 1174s 542ms/step - loss: 0.2292 - mean_squared_error: 0.2292 - val_loss: 0.2640 - val_mean_squared_error: 0.2640
# Epoch 69/500
# 2165/2165 [==============================] - 1034s 477ms/step - loss: 0.2291 - mean_squared_error: 0.2291 - val_loss: 0.2642 - val_mean_squared_error: 0.2642
# Epoch 70/500
# 2165/2165 [==============================] - 927s 428ms/step - loss: 0.2290 - mean_squared_error: 0.2290 - val_loss: 0.2634 - val_mean_squared_error: 0.2634
# Epoch 71/500
# 2165/2165 [==============================] - 892s 412ms/step - loss: 0.2290 - mean_squared_error: 0.2290 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 72/500
# 2165/2165 [==============================] - 885s 409ms/step - loss: 0.2289 - mean_squared_error: 0.2289 - val_loss: 0.2634 - val_mean_squared_error: 0.2634
# Epoch 73/500
# 2165/2165 [==============================] - 891s 412ms/step - loss: 0.2288 - mean_squared_error: 0.2288 - val_loss: 0.2641 - val_mean_squared_error: 0.2641
# Epoch 74/500
# 2165/2165 [==============================] - 889s 411ms/step - loss: 0.2287 - mean_squared_error: 0.2287 - val_loss: 0.2633 - val_mean_squared_error: 0.2633
# Epoch 75/500
# 2165/2165 [==============================] - 913s 422ms/step - loss: 0.2287 - mean_squared_error: 0.2287 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 76/500
# 2165/2165 [==============================] - 897s 414ms/step - loss: 0.2287 - mean_squared_error: 0.2287 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 77/500
# 2165/2165 [==============================] - 914s 422ms/step - loss: 0.2286 - mean_squared_error: 0.2286 - val_loss: 0.2635 - val_mean_squared_error: 0.2635
# Epoch 78/500
# 2165/2165 [==============================] - 898s 415ms/step - loss: 0.2286 - mean_squared_error: 0.2286 - val_loss: 0.2636 - val_mean_squared_error: 0.2636
# Epoch 79/500
# 2165/2165 [==============================] - 917s 424ms/step - loss: 0.2285 - mean_squared_error: 0.2285 - val_loss: 0.2640 - val_mean_squared_error: 0.2640
# Epoch 80/500
# 2165/2165 [==============================] - 880s 406ms/step - loss: 0.2285 - mean_squared_error: 0.2285 - val_loss: 0.2640 - val_mean_squared_error: 0.2640
# Epoch 81/500
# 2165/2165 [==============================] - 1110s 513ms/step - loss: 0.2284 - mean_squared_error: 0.2284 - val_loss: 0.2632 - val_mean_squared_error: 0.2632
# Epoch 82/500
# 2165/2165 [==============================] - 1103s 510ms/step - loss: 0.2283 - mean_squared_error: 0.2283 - val_loss: 0.2629 - val_mean_squared_error: 0.2629
# Epoch 83/500
# 2165/2165 [==============================] - 864s 399ms/step - loss: 0.2284 - mean_squared_error: 0.2284 - val_loss: 0.2635 - val_mean_squared_error: 0.2635
# Epoch 84/500
# 2165/2165 [==============================] - 839s 387ms/step - loss: 0.2283 - mean_squared_error: 0.2283 - val_loss: 0.2637 - val_mean_squared_error: 0.2637
# Epoch 85/500
# 2165/2165 [==============================] - 840s 388ms/step - loss: 0.2282 - mean_squared_error: 0.2282 - val_loss: 0.2633 - val_mean_squared_error: 0.2633
# Epoch 86/500
# 2165/2165 [==============================] - 839s 388ms/step - loss: 0.2281 - mean_squared_error: 0.2281 - val_loss: 0.2632 - val_mean_squared_error: 0.2632
# Epoch 87/500
# 2165/2165 [==============================] - 838s 387ms/step - loss: 0.2280 - mean_squared_error: 0.2280 - val_loss: 0.2630 - val_mean_squared_error: 0.2630
# Epoch 88/500
# 2165/2165 [==============================] - 663s 306ms/step - loss: 0.2280 - mean_squared_error: 0.2280 - val_loss: 0.2636 - val_mean_squared_error: 0.2636
# Epoch 89/500
# 2165/2165 [==============================] - 581s 268ms/step - loss: 0.2279 - mean_squared_error: 0.2279 - val_loss: 0.2631 - val_mean_squared_error: 0.2631
# Epoch 90/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2279 - mean_squared_error: 0.2279 - val_loss: 0.2633 - val_mean_squared_error: 0.2633
# Epoch 91/500
# 2165/2165 [==============================] - 661s 305ms/step - loss: 0.2280 - mean_squared_error: 0.2280 - val_loss: 0.2629 - val_mean_squared_error: 0.2629
# Epoch 92/500
# 2165/2165 [==============================] - 1058s 489ms/step - loss: 0.2279 - mean_squared_error: 0.2279 - val_loss: 0.2627 - val_mean_squared_error: 0.2627
# Epoch 93/500
# 2165/2165 [==============================] - 1058s 489ms/step - loss: 0.2278 - mean_squared_error: 0.2278 - val_loss: 0.2628 - val_mean_squared_error: 0.2628
# Epoch 94/500
# 2165/2165 [==============================] - 1058s 489ms/step - loss: 0.2278 - mean_squared_error: 0.2278 - val_loss: 0.2633 - val_mean_squared_error: 0.2633
# Epoch 95/500
# 2165/2165 [==============================] - 1058s 489ms/step - loss: 0.2277 - mean_squared_error: 0.2277 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 96/500
# 2165/2165 [==============================] - 1057s 488ms/step - loss: 0.2276 - mean_squared_error: 0.2276 - val_loss: 0.2631 - val_mean_squared_error: 0.2631
# Epoch 97/500
# 2165/2165 [==============================] - 1057s 488ms/step - loss: 0.2276 - mean_squared_error: 0.2276 - val_loss: 0.2628 - val_mean_squared_error: 0.2628
# Epoch 98/500
# 2165/2165 [==============================] - 1057s 488ms/step - loss: 0.2275 - mean_squared_error: 0.2275 - val_loss: 0.2629 - val_mean_squared_error: 0.2629
# Epoch 99/500
# 2165/2165 [==============================] - 1056s 488ms/step - loss: 0.2275 - mean_squared_error: 0.2275 - val_loss: 0.2627 - val_mean_squared_error: 0.2627
# Epoch 100/500
# 2165/2165 [==============================] - 1057s 488ms/step - loss: 0.2275 - mean_squared_error: 0.2275 - val_loss: 0.2630 - val_mean_squared_error: 0.2630
# Epoch 101/500
# 2165/2165 [==============================] - 1051s 486ms/step - loss: 0.2274 - mean_squared_error: 0.2274 - val_loss: 0.2627 - val_mean_squared_error: 0.2627
# Epoch 102/500
# 2165/2165 [==============================] - 1071s 495ms/step - loss: 0.2274 - mean_squared_error: 0.2274 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 103/500
# 2165/2165 [==============================] - 1125s 520ms/step - loss: 0.2274 - mean_squared_error: 0.2274 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 104/500
# 2165/2165 [==============================] - 3281s 2s/step - loss: 0.2273 - mean_squared_error: 0.2273 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 105/500
# 2165/2165 [==============================] - 3069s 1s/step - loss: 0.2274 - mean_squared_error: 0.2274 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 106/500
# 2165/2165 [==============================] - 627s 289ms/step - loss: 0.2272 - mean_squared_error: 0.2272 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 107/500
# 2165/2165 [==============================] - 614s 284ms/step - loss: 0.2272 - mean_squared_error: 0.2272 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 108/500
# 2165/2165 [==============================] - 625s 289ms/step - loss: 0.2272 - mean_squared_error: 0.2272 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 109/500
# 2165/2165 [==============================] - 627s 290ms/step - loss: 0.2271 - mean_squared_error: 0.2271 - val_loss: 0.2623 - val_mean_squared_error: 0.2623
# Epoch 110/500
# 2165/2165 [==============================] - 660s 305ms/step - loss: 0.2271 - mean_squared_error: 0.2271 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 111/500
# 2165/2165 [==============================] - 694s 321ms/step - loss: 0.2270 - mean_squared_error: 0.2270 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 112/500
# 2165/2165 [==============================] - 762s 352ms/step - loss: 0.2271 - mean_squared_error: 0.2271 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 113/500
# 2165/2165 [==============================] - 609s 282ms/step - loss: 0.2271 - mean_squared_error: 0.2271 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 114/500
# 2165/2165 [==============================] - 615s 284ms/step - loss: 0.2270 - mean_squared_error: 0.2270 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 115/500
# 2165/2165 [==============================] - 630s 291ms/step - loss: 0.2270 - mean_squared_error: 0.2270 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 116/500
# 2165/2165 [==============================] - 819s 378ms/step - loss: 0.2270 - mean_squared_error: 0.2270 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 117/500
# 2165/2165 [==============================] - 802s 370ms/step - loss: 0.2269 - mean_squared_error: 0.2269 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 118/500
# 2165/2165 [==============================] - 640s 296ms/step - loss: 0.2269 - mean_squared_error: 0.2269 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 119/500
# 2165/2165 [==============================] - 593s 274ms/step - loss: 0.2269 - mean_squared_error: 0.2269 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 120/500
# 2165/2165 [==============================] - 594s 274ms/step - loss: 0.2268 - mean_squared_error: 0.2268 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 121/500
# 2165/2165 [==============================] - 592s 274ms/step - loss: 0.2267 - mean_squared_error: 0.2267 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 122/500
# 2165/2165 [==============================] - 678s 313ms/step - loss: 0.2267 - mean_squared_error: 0.2267 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 123/500
# 2165/2165 [==============================] - 577s 267ms/step - loss: 0.2267 - mean_squared_error: 0.2267 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 124/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2266 - mean_squared_error: 0.2266 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 125/500
# 2165/2165 [==============================] - 581s 268ms/step - loss: 0.2266 - mean_squared_error: 0.2266 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 126/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2266 - mean_squared_error: 0.2266 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 127/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2267 - mean_squared_error: 0.2267 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 128/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2266 - mean_squared_error: 0.2266 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 129/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2266 - mean_squared_error: 0.2266 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 130/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 131/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2266 - mean_squared_error: 0.2266 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 132/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 133/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2264 - mean_squared_error: 0.2264 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 134/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2264 - mean_squared_error: 0.2264 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 135/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2264 - mean_squared_error: 0.2264 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 136/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 137/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 138/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 139/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 140/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 141/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2264 - mean_squared_error: 0.2264 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 142/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 143/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2262 - mean_squared_error: 0.2262 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 144/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2261 - mean_squared_error: 0.2261 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 145/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2261 - mean_squared_error: 0.2261 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 146/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2262 - mean_squared_error: 0.2262 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 147/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2261 - mean_squared_error: 0.2261 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 148/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2261 - mean_squared_error: 0.2261 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 149/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2260 - mean_squared_error: 0.2260 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 150/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2261 - mean_squared_error: 0.2261 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 151/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2260 - mean_squared_error: 0.2260 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 152/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2260 - mean_squared_error: 0.2260 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 153/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 154/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2260 - mean_squared_error: 0.2260 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 155/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 156/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 157/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 158/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2258 - mean_squared_error: 0.2258 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 159/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2258 - mean_squared_error: 0.2258 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 160/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 161/500
# 2165/2165 [==============================] - 578s 267ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 162/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2258 - mean_squared_error: 0.2258 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 163/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2259 - mean_squared_error: 0.2259 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 164/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2258 - mean_squared_error: 0.2258 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 165/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2258 - mean_squared_error: 0.2258 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 166/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2257 - mean_squared_error: 0.2257 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 167/500
# 2165/2165 [==============================] - 694s 321ms/step - loss: 0.2258 - mean_squared_error: 0.2258 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 168/500
# 2165/2165 [==============================] - 896s 414ms/step - loss: 0.2257 - mean_squared_error: 0.2257 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 169/500
# 2165/2165 [==============================] - 624s 288ms/step - loss: 0.2257 - mean_squared_error: 0.2257 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 170/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2257 - mean_squared_error: 0.2257 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 171/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2257 - mean_squared_error: 0.2257 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 172/500
# 2165/2165 [==============================] - 581s 268ms/step - loss: 0.2256 - mean_squared_error: 0.2256 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 173/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2256 - mean_squared_error: 0.2256 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 174/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2257 - mean_squared_error: 0.2257 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 175/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2256 - mean_squared_error: 0.2256 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 176/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2256 - mean_squared_error: 0.2256 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 177/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2255 - mean_squared_error: 0.2255 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 178/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2255 - mean_squared_error: 0.2255 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 179/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2255 - mean_squared_error: 0.2255 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 180/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2255 - mean_squared_error: 0.2255 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 181/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2255 - mean_squared_error: 0.2255 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 182/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2254 - mean_squared_error: 0.2254 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 183/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2254 - mean_squared_error: 0.2254 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 184/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2254 - mean_squared_error: 0.2254 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 185/500
# 2165/2165 [==============================] - 581s 268ms/step - loss: 0.2254 - mean_squared_error: 0.2254 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 186/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 187/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2254 - mean_squared_error: 0.2254 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 188/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 189/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 190/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 191/500
# 2165/2165 [==============================] - 581s 268ms/step - loss: 0.2252 - mean_squared_error: 0.2252 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 192/500
# 2165/2165 [==============================] - 792s 366ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 193/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 194/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 195/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2252 - mean_squared_error: 0.2252 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 196/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 197/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.2604 - val_mean_squared_error: 0.2604
# Epoch 198/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2252 - mean_squared_error: 0.2252 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 199/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.2606 - val_mean_squared_error: 0.2606
# Epoch 200/500
# 2165/2165 [==============================] - 983s 454ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 201/500
# 2165/2165 [==============================] - 983s 454ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 202/500
# 2165/2165 [==============================] - 982s 454ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 203/500
# 2165/2165 [==============================] - 982s 454ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 204/500
# 2165/2165 [==============================] - 986s 455ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 205/500
# 2165/2165 [==============================] - 984s 455ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 206/500
# 2165/2165 [==============================] - 1022s 472ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.2606 - val_mean_squared_error: 0.2606
# Epoch 207/500
# 2165/2165 [==============================] - 1022s 472ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.2606 - val_mean_squared_error: 0.2606
# Epoch 208/500
# 2165/2165 [==============================] - 1022s 472ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 209/500
# 2165/2165 [==============================] - 1021s 472ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2606 - val_mean_squared_error: 0.2606
# Epoch 210/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2606 - val_mean_squared_error: 0.2606
# Epoch 211/500
# 2165/2165 [==============================] - 977s 451ms/step - loss: 0.2249 - mean_squared_error: 0.2249 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 212/500
# 2165/2165 [==============================] - 978s 452ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2606 - val_mean_squared_error: 0.2606
# Epoch 213/500
# 2165/2165 [==============================] - 1035s 478ms/step - loss: 0.2249 - mean_squared_error: 0.2249 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 214/500
# 2165/2165 [==============================] - 991s 458ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2604 - val_mean_squared_error: 0.2604
# Epoch 215/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2252 - mean_squared_error: 0.2252 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 216/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2249 - mean_squared_error: 0.2249 - val_loss: 0.2603 - val_mean_squared_error: 0.2603
# Epoch 217/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2248 - mean_squared_error: 0.2248 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 218/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2249 - mean_squared_error: 0.2249 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 219/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2248 - mean_squared_error: 0.2248 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 220/500
# 2165/2165 [==============================] - 978s 452ms/step - loss: 0.2248 - mean_squared_error: 0.2248 - val_loss: 0.2605 - val_mean_squared_error: 0.2605
# Epoch 221/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2249 - mean_squared_error: 0.2249 - val_loss: 0.2605 - val_mean_squared_error: 0.2605
# Epoch 222/500
# 2165/2165 [==============================] - 982s 454ms/step - loss: 0.2248 - mean_squared_error: 0.2248 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 223/500
# 2165/2165 [==============================] - 1004s 464ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 224/500
# 2165/2165 [==============================] - 1023s 472ms/step - loss: 0.2248 - mean_squared_error: 0.2248 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 225/500
# 2165/2165 [==============================] - 1022s 472ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 226/500
# 2165/2165 [==============================] - 1021s 472ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 227/500
# 2165/2165 [==============================] - 1002s 463ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 228/500
# 2165/2165 [==============================] - 980s 452ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 229/500
# 2165/2165 [==============================] - 982s 453ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2605 - val_mean_squared_error: 0.2605
# Epoch 230/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 231/500
# 2165/2165 [==============================] - 983s 454ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 232/500
# 2165/2165 [==============================] - 983s 454ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 233/500
# 2165/2165 [==============================] - 985s 455ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 234/500
# 2165/2165 [==============================] - 985s 455ms/step - loss: 0.2247 - mean_squared_error: 0.2247 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 235/500
# 2165/2165 [==============================] - 984s 455ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 236/500
# 2165/2165 [==============================] - 984s 454ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2606 - val_mean_squared_error: 0.2606
# Epoch 237/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 238/500
# 2165/2165 [==============================] - 984s 454ms/step - loss: 0.2245 - mean_squared_error: 0.2245 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 239/500
# 2165/2165 [==============================] - 986s 456ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 240/500
# 2165/2165 [==============================] - 995s 460ms/step - loss: 0.2245 - mean_squared_error: 0.2245 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 241/500
# 2165/2165 [==============================] - 1022s 472ms/step - loss: 0.2244 - mean_squared_error: 0.2244 - val_loss: 0.2604 - val_mean_squared_error: 0.2604
# Epoch 242/500
# 2165/2165 [==============================] - 1022s 472ms/step - loss: 0.2245 - mean_squared_error: 0.2245 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 243/500
# 2165/2165 [==============================] - 1025s 473ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 244/500
# 2165/2165 [==============================] - 1021s 472ms/step - loss: 0.2244 - mean_squared_error: 0.2244 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 245/500
# ...
# Epoch 412/500
# 2165/2165 [==============================] - 977s 451ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 413/500
# 2165/2165 [==============================] - 977s 451ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 414/500
# 2165/2165 [==============================] - 977s 451ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 415/500
# 2165/2165 [==============================] - 976s 451ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 416/500
# 2165/2165 [==============================] - 976s 451ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 417/500
# 2165/2165 [==============================] - 1004s 464ms/step - loss: 0.2227 - mean_squared_error: 0.2227 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 418/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 419/500
# 2165/2165 [==============================] - 1023s 473ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 420/500
# 2165/2165 [==============================] - 1023s 472ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 421/500
# 2165/2165 [==============================] - 1001s 462ms/step - loss: 0.2227 - mean_squared_error: 0.2227 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 422/500
# 2165/2165 [==============================] - 975s 450ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 423/500
# 2165/2165 [==============================] - 973s 450ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 424/500
# 2165/2165 [==============================] - 975s 451ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 425/500
# 2165/2165 [==============================] - 977s 451ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 426/500
# 2165/2165 [==============================] - 976s 451ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 427/500
# 2165/2165 [==============================] - 976s 451ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 428/500
# 2165/2165 [==============================] - 976s 451ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 429/500
# 2165/2165 [==============================] - 976s 451ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 430/500
# 2165/2165 [==============================] - 1017s 470ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 431/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 432/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 433/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 434/500
# 2165/2165 [==============================] - 993s 459ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 435/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 436/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Epoch 437/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 438/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 439/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 440/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 441/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2608 - val_mean_squared_error: 0.2608
# Epoch 442/500
# 2165/2165 [==============================] - 984s 455ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 443/500
# 2165/2165 [==============================] - 1025s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 444/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 445/500
# 2165/2165 [==============================] - 1025s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 446/500
# 2165/2165 [==============================] - 1023s 472ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 447/500
# 2165/2165 [==============================] - 987s 456ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 448/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 449/500
# 2165/2165 [==============================] - 982s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 450/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 451/500
# 2165/2165 [==============================] - 982s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 452/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 453/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2225 - mean_squared_error: 0.2225 - val_loss: 0.2609 - val_mean_squared_error: 0.2609
# Epoch 454/500
# 2165/2165 [==============================] - 982s 454ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 455/500
# 2165/2165 [==============================] - 993s 459ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 456/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 457/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2625 - val_mean_squared_error: 0.2625
# Epoch 458/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 459/500
# 2165/2165 [==============================] - 1021s 472ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# Epoch 460/500
# 2165/2165 [==============================] - 981s 453ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 461/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 462/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 463/500
# 2165/2165 [==============================] - 986s 455ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2611 - val_mean_squared_error: 0.2611
# Epoch 464/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 465/500
# 2165/2165 [==============================] - 980s 453ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 466/500
# 2165/2165 [==============================] - 978s 452ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 467/500
# 2165/2165 [==============================] - 979s 452ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 468/500
# 2165/2165 [==============================] - 1001s 462ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2623 - val_mean_squared_error: 0.2623
# Epoch 469/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 470/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 471/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 472/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 473/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2224 - mean_squared_error: 0.2224 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 474/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 475/500
# 2165/2165 [==============================] - 1023s 473ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 476/500
# 2165/2165 [==============================] - 1023s 473ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 477/500
# 2165/2165 [==============================] - 1023s 472ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 478/500
# 2165/2165 [==============================] - 1023s 473ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 479/500
# 2165/2165 [==============================] - 1024s 473ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2614 - val_mean_squared_error: 0.2614
# Epoch 480/500
# 2165/2165 [==============================] - 1022s 472ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2623 - val_mean_squared_error: 0.2623
# Epoch 481/500
# 2165/2165 [==============================] - 612s 283ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 482/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2631 - val_mean_squared_error: 0.2631
# Epoch 483/500
# 2165/2165 [==============================] - 580s 268ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 484/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 485/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2618 - val_mean_squared_error: 0.2618
# Epoch 486/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 487/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2622 - val_mean_squared_error: 0.2622
# Epoch 488/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2624 - val_mean_squared_error: 0.2624
# Epoch 489/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2219 - mean_squared_error: 0.2219 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 490/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2621 - val_mean_squared_error: 0.2621
# Epoch 491/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 492/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 493/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2221 - mean_squared_error: 0.2221 - val_loss: 0.2617 - val_mean_squared_error: 0.2617
# Epoch 494/500
# 2165/2165 [==============================] - 579s 268ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2612 - val_mean_squared_error: 0.2612
# Epoch 495/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2222 - mean_squared_error: 0.2222 - val_loss: 0.2620 - val_mean_squared_error: 0.2620
# Epoch 496/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 497/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2615 - val_mean_squared_error: 0.2615
# Epoch 498/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2619 - val_mean_squared_error: 0.2619
# Epoch 499/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2616 - val_mean_squared_error: 0.2616
# Epoch 500/500
# 2165/2165 [==============================] - 579s 267ms/step - loss: 0.2220 - mean_squared_error: 0.2220 - val_loss: 0.2610 - val_mean_squared_error: 0.2610
# 542/542 [==============================] - 64s 109ms/step
# 相关系数 0.6643326849303509
# WARNING:absl:Found untraced functions such as query_layer_call_fn, query_layer_call_and_return_conditional_losses, key_layer_call_fn, key_layer_call_and_return_conditional_losses, value_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: E:/xuanxuan/xuanxuan_transformer_classify_regress_CN05_morev_sm2_lr0.001\assets
# INFO:tensorflow:Assets written to: E:/xuanxuan/xuanxuan_transformer_classify_regress_CN05_morev_sm2_lr0.001\assets
