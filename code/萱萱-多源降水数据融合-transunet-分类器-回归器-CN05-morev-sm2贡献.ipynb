# %%
import Auto_paint_self

# %%
CN05_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\CN05.1_Pre_1961_2021_daily_025x025.nc','pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
CMO_RPH,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\CMORPH_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
ERA5_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\ERA5_China_2001_2022_2.nc','tp','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
td2m,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\2m-dewpoint-temperature-day.nc','d2m','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
t2m,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\2m-temperature-day.nc','t2m','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
sp,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\Surface-pressure-day.nc','sp','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
sm,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'D:\ERA5 dayly data on Single levels from 1979 to present\single 0.25\Volumetric-soil-water-layer-1-day.nc','swvl1','yes','time','2001-01-01','2021-12-31','yes','longitude','yes','latitude',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
GPM_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\GPM_China_2001_2022_time.nc','precipitation','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
GSMAP_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\GSMAP_China_2001_2022_time.nc','Pre_daily','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
MSWEP_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\MSWEP_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
PERSIANN_CDR_PRE,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'E:\Multi-Sources_Precipitation_NC_2001_2022\PERSIANN_CDR_PRE_China_2001_2022_2.nc','Pre','yes','time','2001-01-01','2021-12-31','yes','lon','yes','lat',18.0,53.5,73.5,135.0,0.25,0.25,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
# Out:
# F:\anaconda\envs\tensorflow\lib\site-packages\xarray\coding\times.py:170: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
import numpy as np
vx=np.zeros((CMO_RPH.shape[0],CMO_RPH.shape[1],CMO_RPH.shape[2],10))
vy=np.zeros((CN05_PRE.shape[0],CN05_PRE.shape[1],CN05_PRE.shape[2]),dtype='int32')
CN05_PRE=CN05_PRE[:,::-1,:]
CN05_PRE=np.nan_to_num(CN05_PRE,nan=0)
vx[:,:,:,0]=CMO_RPH
vx[:,:,:,1]=ERA5_PRE
vx[:,:,:,2]=GPM_PRE
vx[:,:,:,3]=GSMAP_PRE
vx[:,:,:,4]=MSWEP_PRE
vx[:,:,:,5]=PERSIANN_CDR_PRE
vx[:,:,:,6]=td2m
vx[:,:,:,7]=t2m
vx[:,:,:,8]=sp
vx[:,:,:,9]=sm
vx=np.nan_to_num(vx,nan=0)
for i in range(CN05_PRE.shape[1]):
    for j in range(CN05_PRE.shape[2]):
        vy[np.array(CN05_PRE[:,i,j])<0.1,i,j]=0
        vy[np.array(CN05_PRE[:,i,j])>=0.1,i,j]=1

vx=(vx-np.nanmean(vx,axis=0))/np.nanstd(vx,axis=0)
vx=np.nan_to_num(vx,nan=0)
CN05_PRE=(CN05_PRE-np.nanmean(CN05_PRE,axis=0))/np.nanstd(CN05_PRE,axis=0)
CN05_PRE=np.nan_to_num(CN05_PRE,nan=0)
# Out:
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_12304\1891578375.py:22: RuntimeWarning: invalid value encountered in divide
#   vx=(vx-np.nanmean(vx,axis=0))/np.nanstd(vx,axis=0)
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_12304\1891578375.py:24: RuntimeWarning: invalid value encountered in divide
#   CN05_PRE=(CN05_PRE-np.nanmean(CN05_PRE,axis=0))/np.nanstd(CN05_PRE,axis=0)

# %%
print(np.isnan(vx).any(),np.isnan(CN05_PRE).any(),np.isnan(vy).any())
# Out:
# False False False

# %%
from keras.models import load_model
import tensorflow as tf
with tf.device('/CPU:0'):
    model=load_model(r'E:/xuanxuan/xuanxuan_transunet_classify_CN05_morev_sm2')
    vx_last=model.predict(vx,batch_size=40)
# Out:
# 192/192 [==============================] - 156s 810ms/step

# %%
vx_last[vx_last<=0.5]=0
vx_last[vx_last>0.5]=1

# %%
vx_new=np.zeros((CMO_RPH.shape[0],CMO_RPH.shape[1],CMO_RPH.shape[2],11))
vx_new[:,:,:,:10]=vx
vx_new[:,:,:,10]=vx_last.reshape(vx_last.shape[0],vx_last.shape[1],vx_last.shape[2])

# %%
print(np.isnan(vx_new).any())
# Out:
# False

# %%
from keras.models import load_model
index=int((1-0.2)*CN05_PRE.shape[0])
trainy=CN05_PRE[:index,:,:]
testy=CN05_PRE[index:,:,:]
trainx=vx_new[:index,:,:,:]
testx=vx_new[index:,:,:,:]
with tf.device('/CPU:0'):
    model=load_model(r'E:/xuanxuan/xuanxuan_transunet_classify_regress_CN05_morev_sm2')

# %%
with tf.device('/CPU:0'):
    predicty=model.predict(testx,batch_size=40)
# Out:
# 39/39 [==============================] - 32s 798ms/step

# %%
testy=testy.reshape(testy.shape[0],testy.shape[1],testy.shape[2],1)

# %%
import shap
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

# ==============================================================================
# 1. 准备工作：定义变量名
# ==============================================================================

# 你提供的 11 个特征名称 (请确保顺序与 testx 的通道顺序严格一致)
feature_names = [
    'C_R', 'E_P', 'TD2M', 'T2M', 'SP', 
    'SM', 'G_P', 'GS_P', 'M_P', 'P_C', 'CLASS'
]

# ==============================================================================
# 2. 计算原始 SHAP 值 (不取绝对值，不求平均)
# ==============================================================================
# 注意：这里需要重新定义计算函数，确保返回带有正负号的原始值

def create_simple_wrapped_model_for_shap(original_model, x_flat_len, output_channel_idx=None):
    """(保持不变) 创建 SHAP 包装模型"""
    shap_input = tf.keras.Input(shape=(x_flat_len,), dtype=tf.float32)
    original_input_shape = original_model.input_shape[1:] 
    reshape_x = tf.keras.layers.Reshape(original_input_shape)(shap_input)
    model_output = original_model(reshape_x)
    
    if K.ndim(model_output) == 4: 
        if output_channel_idx is not None:
            output_slice = model_output[..., output_channel_idx] 
            scalar_output = tf.reduce_mean(tf.reshape(output_slice, (tf.shape(output_slice)[0], -1)), axis=1) 
        else:
            scalar_output = tf.reduce_mean(tf.reshape(model_output, (tf.shape(model_output)[0], -1)), axis=1) 
    else: 
        scalar_output = tf.reduce_mean(tf.reshape(model_output, (tf.shape(model_output)[0], -1)), axis=1) 
    
    final_output = tf.expand_dims(scalar_output, axis=-1)
    return tf.keras.Model(inputs=shap_input, outputs=final_output)

def get_shap_values_2d(model, x_data, feature_names):
    """
    计算 SHAP 值并将 4D (Samples, H, W, C) 聚合为 2D (Samples, C) 用于绘图
    """
    # 1. 采样 (如果数据太多，取 200-500 个样本以防画图太慢或重叠)
    num_samples = 300 
    if x_data.shape[0] > num_samples:
        np.random.seed(42)
        idx = np.random.choice(x_data.shape[0], num_samples, replace=False)
        current_x = x_data[idx]
    else:
        current_x = x_data
    
    sample_x_shape = current_x.shape[1:]
    x_flat_len = int(np.prod(sample_x_shape))
    flat_x = current_x.reshape(len(current_x), -1)
    
    # 2. 计算 SHAP
    print("正在计算 SHAP 值 (这可能需要几分钟)...")
    
    # 针对第0个输出通道计算 (假设做单目标回归/分类)
    target_output_idx = 0 
    
    with tf.device('/CPU:0'): # 使用 CPU 防止 OOM
        wrapped_model = create_simple_wrapped_model_for_shap(
            model, x_flat_len, output_channel_idx=target_output_idx
        )
        explainer = shap.GradientExplainer(wrapped_model, flat_x)
        shap_values_list = explainer.shap_values(flat_x)
    
    # 提取结果
    if isinstance(shap_values_list, list):
        raw_shap = shap_values_list[0]
    else:
        raw_shap = shap_values_list
        
    # Reshape 回 4D: (Samples, Lat, Lon, Channels)
    shap_4d = raw_shap.reshape(len(current_x), *sample_x_shape)
    
    print("SHAP 计算完成，正在聚合空间维度...")

    # 3. 空间聚合 (Spatial Aggregation)
    # 将 (Lat, Lon) 维度平均，得到每个样本该变量的"平均影响"
    # shap_values_2d shape: (Samples, Channels)
    shap_values_2d = np.mean(shap_4d, axis=(1, 2))
    
    # 同样处理特征值 X，用于决定颜色 (红/蓝)
    # feature_values_2d shape: (Samples, Channels)
    feature_values_2d = np.mean(current_x, axis=(1, 2))
    
    return shap_values_2d, feature_values_2d

# ==============================================================================
# 3. 执行绘图
# ==============================================================================

# 假设你的 testx 和 model 已经准备好
# 检查维度匹配
if testx.shape[-1] != len(feature_names):
    print(f"警告: testx 通道数 ({testx.shape[-1]}) 与提供的名字数量 ({len(feature_names)}) 不一致！")
else:
    # 获取绘图所需的数据
    shap_vals, feature_vals = get_shap_values_2d(model, testx, feature_names)

    # 创建画布
    plt.figure(figsize=(12, 10)) # 调整大小以适应标签
    
    # 绘制标准散点图 (Beeswarm plot)
    shap.summary_plot(
        shap_vals, 
        feature_vals, 
        feature_names=feature_names,
        plot_type="dot", # 显式指定为散点图
        show=False,       # 先不显示，以便我们可以添加标题或保存
        max_display=len(feature_names) # 显示所有特征
    )

    # 设置标题
    plt.title('SHAP Feature Importance', fontsize=20)
    
    # 保存图片
    plt.savefig('E:/SHAP_Beeswarm_Output.png', dpi=300, bbox_inches='tight')
    
    # 显示
    plt.show()
# Out:
# C:\Users\TBYC\AppData\Local\Temp\ipykernel_12304\4029318870.py:5: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(

# %%
import numpy as np

# ==============================================================================
# 1. 准备特征名称 (必须与模型输入的通道顺序严格对应)
# ==============================================================================
feature_names_arr = np.array([
    'C_R','E_P','TD2M','T2M','SP','SM',
    'G_P','GS_P','M_P','P_C','CLASS'
])

# ==============================================================================
# 2. 计算权重 (核心逻辑：绝对值 -> 求均值 -> 转百分比)
# ==============================================================================
# shap_values_2d 是之前计算好的 (Samples, Features) 数组

# 第一步：取绝对值并计算平均 (Global Importance)
global_importance = np.mean(np.abs(shap_vals), axis=0)

# 第二步：计算总和
total_importance = np.sum(global_importance)

# 第三步：转换为百分比 (这就是你要传入绘图函数的 weights)
if total_importance == 0:
    weights = np.zeros_like(global_importance)
else:
    weights = (global_importance / total_importance) * 100

# 打印一下看看数值，确认没有问题
print("特征贡献度百分比 (Weights):")
for n, w in zip(feature_names_arr, weights):
    print(f"{n}: {w:.2f}%")
# Out:
# 特征贡献度百分比 (Weights):
# C_R: 1.94%
# E_P: 3.99%
# TD2M: 1.45%
# T2M: 2.88%
# SP: 10.96%
# SM: 0.22%
# G_P: 35.85%
# GS_P: 28.53%
# M_P: 1.67%
# P_C: 6.62%
# CLASS: 5.88%

# %%
def Auto_petal_plot(v,labels,selfcolor=None,labelsize=20,title=' ',ifsave='no',savename=None):
    import numpy as np
    import matplotlib.pyplot as plt

    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus']=False

    if selfcolor is not None and isinstance(selfcolor, str):
        try:
            selfcolor = getattr(plt.cm, selfcolor)
        except AttributeError:
            selfcolor = plt.cm.viridis
    elif selfcolor is None:
         selfcolor = plt.cm.viridis

    v_array = np.array(v)
    labels_array = np.array(labels)

    if len(v_array) == 0:
        fig, ax = plt.subplots(subplot_kw={'polar': True}, figsize=(16,16), facecolor='white')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(title, y=1.05, fontsize=labelsize)
        plt.show()
        if ifsave == 'yes' and savename:
            fig.savefig(savename, dpi=300)
        return

    sorted_indices = np.argsort(v_array)[::-1]
    labels_sorted = labels_array[sorted_indices]
    v_values_sorted = v_array[sorted_indices]

    N = len(v_values_sorted)
    theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)

    min_val_orig = np.min(v_values_sorted)
    max_val_orig = np.max(v_values_sorted)
    range_val_orig = max_val_orig - min_val_orig

    scaled_min_display = 0.5
    scaled_max_display = 1.5
    if N == 0: 
        heights_for_plot = np.array([])
    elif range_val_orig < 1e-9:
        heights_for_plot = np.full_like(v_values_sorted, scaled_min_display, dtype=float)
    else:
        heights_for_plot = (v_values_sorted - min_val_orig) / range_val_orig * (scaled_max_display - scaled_min_display) + scaled_min_display

    gap = 0.1
    width = (2 * np.pi / N) * (1 - gap)

    fig, ax = plt.subplots(subplot_kw={'polar': True}, figsize=(16,16),facecolor = 'white')
    ax.spines['polar'].set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])
    if not(isinstance(selfcolor, list)):
        colors_to_use = selfcolor(np.linspace(0.2, 0.8, N))
    else:
        colors_to_use=selfcolor
    bars = ax.bar(theta, heights_for_plot, width=width, bottom=0.0, 
                  color=colors_to_use, 
                  edgecolor='none')

    max_plot_height_val = np.max(heights_for_plot) if N > 0 else 1.0
    label_radial_offset = max_plot_height_val * 0.2 +((labelsize-20)*0.005)

    for i in range(N):
        bar_plotted_height = heights_for_plot[i]
        original_value_for_label = v_values_sorted[i]
        current_label_text = labels_sorted[i]
        
        angle_rad_for_position = theta[i]

        r_label_position = bar_plotted_height + label_radial_offset
        
        angle_deg_of_petal = np.degrees(angle_rad_for_position)
        
        text_rotation_tangential = angle_deg_of_petal + 90.0
        final_text_rotation = text_rotation_tangential
        normalized_angle = final_text_rotation % 360
        if normalized_angle > 90 and normalized_angle < 270:
            final_text_rotation += 180.0
        
        ax.text(angle_rad_for_position, r_label_position, f'{current_label_text}: {original_value_for_label:.2f}',
                ha='center', va='center', fontsize=labelsize,
                rotation=final_text_rotation, rotation_mode='anchor')

    ax.set_theta_zero_location('N')
    ax.set_title(title,y = 1.2,fontsize = labelsize)
    plt.show()
    
    if ifsave == 'yes' and savename is not None:
        fig.savefig(savename, dpi=300)

# %%
# ==============================================================================
# 3. 绘图
# ==============================================================================

# 定义颜色列表 (11个颜色，对应11个特征)
# 颜色顺序建议：从最深红(最重要)到最深蓝(最不重要)
my_colors = [
    "#6D011F", "#B72230", "#DC6D57", "#F6B293", "#FBE3D5", # 红/橙色系 (前5名)
    "#F2EAE4",                                             # 中间色
    "#E9F1F4", "#B6D7E8", "#6DADD1", "#317CB7", "#104680"  # 蓝色系 (后5名)
]

# 调用你的函数
Auto_petal_plot(
    v=weights,                 # 刚才计算出的百分比
    labels=feature_names_arr,  # 特征名称
    selfcolor=my_colors,       # 颜色列表
    labelsize=30,              # 字体大小
    title='Contribution of Inputs(%)', 
    ifsave='yes',              # 如果想保存，设为 'yes'
    savename='E:/SHAP_Petal_Contribution.png'
)
